# %% [markdown]
# ## OrthoDB Data
#
# Scripts for the download and basic preparation of fasta files containing ortholog sequences.
#
# The source is OrthoDB's api.

# %%
import requests, time
import sys

from tqdm import tqdm
import pandas as pd
import json
from datasets.orthodb_preparation.data_utils import *

BASE = "https://data.orthodb.org/v12/download/odb_data_dump"
DATASET_ROOT= Path("../fasta_files")
OUT = Path("dumps")
OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# #### Download of resources and raw files
# Get index files from api

# %%
files = [
    "odb12v2_levels.tab.gz",
    "odb12v2_level2species.tab.gz",
    "odb12v2_OG2genes.tab.gz",
    "odb12v2_genes.tab.gz",
    "odb12v2_OGs.tab.gz"
]
for fn in files:
    url = f"{BASE}/{fn}"
    dst = OUT / fn
    if dst.exists() and dst.stat().st_size > 0:
        continue
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        total=int(r.headers.get("content-length", 0))
        with open(dst, "wb") as f, tqdm(total=total, unit="B", unit_scale=True, desc=fn) as pbar:
            for chunk in r.iter_content(chunk_size=1<<20):
                if chunk: f.write(chunk); pbar.update(len(chunk))
# Out:
# odb12v2_levels.tab.gz: 100%|██████████| 16.0k/16.0k [00:00<?, ?B/s]
# odb12v2_level2species.tab.gz: 100%|██████████| 247k/247k [00:00<00:00, 2.34MB/s]
# odb12v2_OG2genes.tab.gz: 100%|██████████| 4.81G/4.81G [04:04<00:00, 19.7MB/s]
# odb12v2_genes.tab.gz: 100%|██████████| 4.84G/4.84G [03:39<00:00, 22.0MB/s]
# odb12v2_OGs.tab.gz: 100%|██████████| 134M/134M [00:05<00:00, 24.8MB/s]

# %% [markdown]
# Get orthologous groups of a clade

# %%
CLADE = "Mammalia"  # Vertebrate/Mammalia/Eukaryota/…

levels = pd.read_csv(
    OUT/"odb12v2_levels.tab.gz",
    sep="\t", header=None, compression="gzip",
    names=["level_taxid","name","nr_genes","nr_ogs","nr_species"]  # <-- 5 colonne
)

level_id = levels.loc[levels["name"]==CLADE, "level_taxid"].iloc[0]
print("Clade:", CLADE, "→ level_taxid:", level_id)

ogs_df = pd.read_csv(
    OUT/"odb12v2_OGs.tab.gz",
    sep="\t", header=None, compression="gzip",
    names=["og_id","level_taxid","og_name"]
)

ogs_in_clade = ogs_df.loc[ogs_df["level_taxid"]==level_id, "og_id"].drop_duplicates()
print("OG trovati:", len(ogs_in_clade))

Path("ogs.txt").write_text("\n".join(ogs_in_clade.tolist()))
# Out:
# Clade: Mammalia → level_taxid: 40674
# OG trovati: 42608
# 591195

# %% [markdown]
# Download every fasta file in chosen clade

# %%
API = "https://data.orthodb.org/v12/fasta"
raw_dir = DATASET_ROOT / "orthodb_v12/raw"; raw_dir.mkdir(parents=True, exist_ok=True)

# if not none, max number of files downloaded
max_download_count = 500

def download_cds_for_og(og_id):
    url = f"{API}?id={og_id}&seqtype=cds"
    r = requests.get(url, timeout=60)
    r.raise_for_status()
    (raw_dir/f"{og_id}.cds.fasta").write_text(r.text, encoding="utf-8")

ogs = [og for og in Path("ogs.txt").read_text().splitlines() if og]
total_iter = min(max_download_count, len(ogs)) if max_download_count else len(ogs)


for i, og in enumerate(tqdm(ogs[:total_iter], total=min(total_iter, max_download_count), desc="Scarico OG", unit="og", file=sys.stdout), 1):
    if not og: continue
    out = raw_dir/f"{og}.cds.fasta"
    if out.exists() and out.stat().st_size>0:
        continue
    try:
        download_cds_for_og(og)
    except Exception as e:
        tqdm.write(f"Failed {i}: {e}")
    if i % 50 == 0:
        time.sleep(1)

    tqdm.write(f"Downloaded {i} {og}")
# Out:
# Downloaded 1 100009at40674
# Downloaded 2 100011at40674
# Downloaded 3 100068at40674
# Downloaded 4 100125at40674
# Downloaded 5 100128at40674
# Downloaded 6 100187at40674
# Downloaded 7 100244at40674
# Downloaded 8 100287at40674
# Downloaded 9 100314at40674
# Downloaded 10 100670at40674
# Downloaded 11 100672at40674
# Downloaded 12 100717at40674
# Downloaded 13 100729at40674
# Downloaded 14 100751at40674
# Downloaded 15 100791at40674
# Downloaded 16 100882at40674
# Downloaded 17 100969at40674
# Downloaded 18 100974at40674
# Downloaded 19 10105at40674
# Downloaded 20 101211at40674
# Downloaded 21 101238at40674
# Downloaded 22 101254at40674
# Downloaded 23 101279at40674
# Downloaded 24 10129at40674
# Downloaded 25 101550at40674
# Downloaded 26 101553at40674
# Downloaded 27 101567at40674
# Downloaded 28 102071at40674
# Downloaded 29 102099at40674
# Downloaded 30 102111at40674
# Downloaded 31 102314at40674
# Downloaded 32 102321at40674
# Downloaded 33 102443at40674
# Downloaded 34 102455at40674
# Downloaded 35 102476at40674
# Downloaded 36 10271at40674
# Downloaded 37 102775at40674
# Downloaded 38 102791at40674
# Downloaded 39 102837at40674
# Downloaded 40 1030at40674
# Downloaded 41 103134at40674
# Downloaded 42 103140at40674
# Downloaded 43 103214at40674
# Downloaded 44 103249at40674
# Downloaded 45 103280at40674
# Downloaded 46 103294at40674
# Downloaded 47 10332at40674
# Downloaded 48 10333at40674
# Downloaded 49 103424at40674
# Downloaded 50 103430at40674
# Downloaded 51 103472at40674
# Downloaded 52 103633at40674
# Downloaded 53 103647at40674
# Downloaded 54 10367at40674
# Downloaded 55 103784at40674
# Downloaded 56 10392at40674
# Downloaded 57 104008at40674
# Downloaded 58 104048at40674
# Downloaded 59 1040at40674
# Downloaded 60 10421at40674
# Downloaded 61 10424at40674
# Downloaded 62 104253at40674
# Downloaded 63 104259at40674
# Downloaded 64 10428at40674
# Downloaded 65 104324at40674
# Downloaded 66 104505at40674
# Downloaded 67 104543at40674
# Downloaded 68 10458at40674
# Downloaded 69 104764at40674
# Downloaded 70 104826at40674
# Downloaded 71 104941at40674
# Downloaded 72 104961at40674
# Downloaded 73 105005at40674
# Downloaded 74 105056at40674
# Downloaded 75 105076at40674
# Downloaded 76 105090at40674
# Downloaded 77 105098at40674
# Downloaded 78 105125at40674
# Downloaded 79 10522at40674
# Downloaded 80 105303at40674
# Downloaded 81 105353at40674
# Downloaded 82 105505at40674
# Downloaded 83 105544at40674
# Downloaded 84 105546at40674
# Downloaded 85 105755at40674
# Downloaded 86 105795at40674
# Downloaded 87 105796at40674
# Downloaded 88 105862at40674
# Downloaded 89 105918at40674
# Downloaded 90 10597at40674
# Downloaded 91 105993at40674
# Downloaded 92 105at40674
# Downloaded 93 106068at40674
# Downloaded 94 106081at40674
# Downloaded 95 106115at40674
# Downloaded 96 106189at40674
# Downloaded 97 10622at40674
# Downloaded 98 10636at40674
# Downloaded 99 10637at40674
# Downloaded 100 106619at40674
# Downloaded 101 10667at40674
# Downloaded 102 106725at40674
# Downloaded 103 10675at40674
# Downloaded 104 106787at40674
# Downloaded 105 106831at40674
# Downloaded 106 106840at40674
# Downloaded 107 106895at40674
# Downloaded 108 106975at40674
# Downloaded 109 107045at40674
# Downloaded 110 107054at40674
# Downloaded 111 107168at40674
# Downloaded 112 10746at40674
# Downloaded 113 10750at40674
# Downloaded 114 107523at40674
# Downloaded 115 107552at40674
# Downloaded 116 107623at40674
# Downloaded 117 107722at40674
# Downloaded 118 107756at40674
# Downloaded 119 107812at40674
# Downloaded 120 107884at40674
# Downloaded 121 107889at40674
# Downloaded 122 107972at40674
# Downloaded 123 108013at40674
# Downloaded 124 108022at40674
# Downloaded 125 10805at40674
# Downloaded 126 108141at40674
# Downloaded 127 108142at40674
# Downloaded 128 108147at40674
# Downloaded 129 108331at40674
# Downloaded 130 108349at40674
# Downloaded 131 108396at40674
# Downloaded 132 10857at40674
# Downloaded 133 108615at40674
# Downloaded 134 108780at40674
# Downloaded 135 108809at40674
# Downloaded 136 108820at40674
# Downloaded 137 10888at40674
# Downloaded 138 108900at40674
# Downloaded 139 108911at40674
# Downloaded 140 108995at40674
# Downloaded 141 108999at40674
# Downloaded 142 109019at40674
# Downloaded 143 109224at40674
# Downloaded 144 109347at40674
# Downloaded 145 109408at40674
# Downloaded 146 109518at40674
# Downloaded 147 109537at40674
# Downloaded 148 109556at40674
# Downloaded 149 109578at40674
# Downloaded 150 109660at40674
# Downloaded 151 109689at40674
# Downloaded 152 109712at40674
# Downloaded 153 109796at40674
# Downloaded 154 109981at40674
# Downloaded 155 1101at40674
# Downloaded 156 110308at40674
# Downloaded 157 110340at40674
# Downloaded 158 110393at40674
# Downloaded 159 11049at40674
# Downloaded 160 110522at40674
# Downloaded 161 110554at40674
# Downloaded 162 110658at40674
# Downloaded 163 110747at40674
# Downloaded 164 1107at40674
# Downloaded 165 11092at40674
# Downloaded 166 111008at40674
# Downloaded 167 111081at40674
# Downloaded 168 111125at40674
# Downloaded 169 1112at40674
# Downloaded 170 111325at40674
# Downloaded 171 111385at40674
# Downloaded 172 111412at40674
# Downloaded 173 111420at40674
# Downloaded 174 11157at40674
# Downloaded 175 111739at40674
# Downloaded 176 111763at40674
# Downloaded 177 111842at40674
# Downloaded 178 11184at40674
# Downloaded 179 11191at40674
# Downloaded 180 111963at40674
# Downloaded 181 111985at40674
# Downloaded 182 112035at40674
# Downloaded 183 112070at40674
# Downloaded 184 112093at40674
# Downloaded 185 112165at40674
# Downloaded 186 112206at40674
# Downloaded 187 112253at40674
# Downloaded 188 112271at40674
# Downloaded 189 112326at40674
# Downloaded 190 112452at40674
# Downloaded 191 112494at40674
# Downloaded 192 112496at40674
# Downloaded 193 112532at40674
# Downloaded 194 112608at40674
# Downloaded 195 112657at40674
# Downloaded 196 112672at40674
# Downloaded 197 112739at40674
# Downloaded 198 112896at40674
# Downloaded 199 112984at40674
# Downloaded 200 112988at40674
# Downloaded 201 113020at40674
# Downloaded 202 113022at40674
# Downloaded 203 11306at40674
# Downloaded 204 113102at40674
# Downloaded 205 113225at40674
# Downloaded 206 113333at40674
# Downloaded 207 11334at40674
# Downloaded 208 113390at40674
# Downloaded 209 113631at40674
# Downloaded 210 113664at40674
# Downloaded 211 113694at40674
# Downloaded 212 113726at40674
# Downloaded 213 113730at40674
# Downloaded 214 113884at40674
# Downloaded 215 113940at40674
# Downloaded 216 1139at40674
# Downloaded 217 114024at40674
# Downloaded 218 114026at40674
# Downloaded 219 114209at40674
# Downloaded 220 114249at40674
# Downloaded 221 114256at40674
# Downloaded 222 114307at40674
# Downloaded 223 114510at40674
# Downloaded 224 114533at40674
# Downloaded 225 114640at40674
# Downloaded 226 114920at40674
# Downloaded 227 114989at40674
# Downloaded 228 115012at40674
# Downloaded 229 115107at40674
# Downloaded 230 115168at40674
# Downloaded 231 115206at40674
# Downloaded 232 115322at40674
# Downloaded 233 11543at40674
# Downloaded 234 11544at40674
# Downloaded 235 115472at40674
# Downloaded 236 115532at40674
# Downloaded 237 115537at40674
# Downloaded 238 115550at40674
# Downloaded 239 115605at40674
# Downloaded 240 115842at40674
# Downloaded 241 115852at40674
# Downloaded 242 115878at40674
# Downloaded 243 115900at40674
# Downloaded 244 116039at40674
# Downloaded 245 116043at40674
# Downloaded 246 116051at40674
# Downloaded 247 116068at40674
# Downloaded 248 1160at40674
# Downloaded 249 116110at40674
# Downloaded 250 116134at40674
# Downloaded 251 116166at40674
# Downloaded 252 116204at40674
# Downloaded 253 116220at40674
# Downloaded 254 116375at40674
# Downloaded 255 116452at40674
# Downloaded 256 116464at40674
# Downloaded 257 116487at40674
# Downloaded 258 116556at40674
# Downloaded 259 116580at40674
# Downloaded 260 116638at40674
# Downloaded 261 116678at40674
# Downloaded 262 116742at40674
# Downloaded 263 11692at40674
# Downloaded 264 116948at40674
# Downloaded 265 116968at40674
# Downloaded 266 117072at40674
# Downloaded 267 11717at40674
# Downloaded 268 117224at40674
# Downloaded 269 117386at40674
# Downloaded 270 117391at40674
# Downloaded 271 117406at40674
# Downloaded 272 117590at40674
# Downloaded 273 11763at40674
# Downloaded 274 11774at40674
# Downloaded 275 117759at40674
# Downloaded 276 117938at40674
# Downloaded 277 118032at40674
# Downloaded 278 118064at40674
# Downloaded 279 118078at40674
# Downloaded 280 118113at40674
# Downloaded 281 118174at40674
# Downloaded 282 118192at40674
# Downloaded 283 118231at40674
# Downloaded 284 118246at40674
# Downloaded 285 118348at40674
# Downloaded 286 118591at40674
# Downloaded 287 118616at40674
# Downloaded 288 118708at40674
# Downloaded 289 118714at40674
# Downloaded 290 118798at40674
# Downloaded 291 118827at40674
# Downloaded 292 118914at40674
# Downloaded 293 118968at40674
# Downloaded 294 119116at40674
# Downloaded 295 119248at40674
# Downloaded 296 11931at40674
# Downloaded 297 119366at40674
# Downloaded 298 119414at40674
# Downloaded 299 119458at40674
# Downloaded 300 119481at40674
# Downloaded 301 119589at40674
# Downloaded 302 11964at40674
# Downloaded 303 119848at40674
# Downloaded 304 119863at40674
# Downloaded 305 119894at40674
# Downloaded 306 119929at40674
# Downloaded 307 120046at40674
# Downloaded 308 120122at40674
# Downloaded 309 120140at40674
# Downloaded 310 12019at40674
# Downloaded 311 120376at40674
# Downloaded 312 120397at40674
# Downloaded 313 120467at40674
# Downloaded 314 120584at40674
# Downloaded 315 120635at40674
# Downloaded 316 12071at40674
# Downloaded 317 120746at40674
# Downloaded 318 120868at40674
# Downloaded 319 120915at40674
# Downloaded 320 120917at40674
# Downloaded 321 120919at40674
# Downloaded 322 121005at40674
# Downloaded 323 121035at40674
# Downloaded 324 12110at40674
# Downloaded 325 121118at40674
# Downloaded 326 121361at40674
# Downloaded 327 121383at40674
# Downloaded 328 121425at40674
# Downloaded 329 121650at40674
# Downloaded 330 12170at40674
# Downloaded 331 121740at40674
# Downloaded 332 121754at40674
# Downloaded 333 12175at40674
# Downloaded 334 12190at40674
# Downloaded 335 121989at40674
# Downloaded 336 122026at40674
# Downloaded 337 122326at40674
# Downloaded 338 122375at40674
# Downloaded 339 122406at40674
# Downloaded 340 122429at40674
# Downloaded 341 122502at40674
# Downloaded 342 122504at40674
# Downloaded 343 122506at40674
# Downloaded 344 122605at40674
# Downloaded 345 122634at40674
# Downloaded 346 122646at40674
# Downloaded 347 122883at40674
# Downloaded 348 12296at40674
# Downloaded 349 123260at40674
# Downloaded 350 123317at40674
# Downloaded 351 12359at40674
# Downloaded 352 12361at40674
# Downloaded 353 123691at40674
# Downloaded 354 1236at40674
# Downloaded 355 123715at40674
# Downloaded 356 123748at40674
# Downloaded 357 123812at40674
# Downloaded 358 123844at40674
# Downloaded 359 123854at40674
# Downloaded 360 123891at40674
# Downloaded 361 123934at40674
# Downloaded 362 123945at40674
# Downloaded 363 123968at40674
# Downloaded 364 123994at40674
# Downloaded 365 124016at40674
# Downloaded 366 124024at40674
# Downloaded 367 12419at40674
# Downloaded 368 124223at40674
# Downloaded 369 12424at40674
# Downloaded 370 124251at40674
# Downloaded 371 124255at40674
# Downloaded 372 124297at40674
# Downloaded 373 124302at40674
# Downloaded 374 124453at40674
# Downloaded 375 124471at40674
# Downloaded 376 124546at40674
# Downloaded 377 124635at40674
# Downloaded 378 124652at40674
# Downloaded 379 124688at40674
# Downloaded 380 124761at40674
# Downloaded 381 124900at40674
# Downloaded 382 124940at40674
# Downloaded 383 125054at40674
# Downloaded 384 12514at40674
# Downloaded 385 125158at40674
# Downloaded 386 125227at40674
# Downloaded 387 125319at40674
# Downloaded 388 12540at40674
# Downloaded 389 125428at40674
# Downloaded 390 125469at40674
# Downloaded 391 125529at40674
# Downloaded 392 12562at40674
# Downloaded 393 125697at40674
# Downloaded 394 125904at40674
# Downloaded 395 12593at40674
# Downloaded 396 125946at40674
# Downloaded 397 126018at40674
# Downloaded 398 12605at40674
# Downloaded 399 126308at40674
# Downloaded 400 126375at40674
# Downloaded 401 126770at40674
# Downloaded 402 126805at40674
# Downloaded 403 126849at40674
# Downloaded 404 12688at40674
# Downloaded 405 126968at40674
# Downloaded 406 12699at40674
# Downloaded 407 127013at40674
# Downloaded 408 127055at40674
# Downloaded 409 127189at40674
# Downloaded 410 12726at40674
# Downloaded 411 127309at40674
# Downloaded 412 127321at40674
# Downloaded 413 127360at40674
# Downloaded 414 127446at40674
# Downloaded 415 127495at40674
# Downloaded 416 127519at40674
# Downloaded 417 127604at40674
# Downloaded 418 127689at40674
# Downloaded 419 127784at40674
# Downloaded 420 127913at40674
# Downloaded 421 127924at40674
# Downloaded 422 128064at40674
# Downloaded 423 128236at40674
# Downloaded 424 128259at40674
# Downloaded 425 128329at40674
# Downloaded 426 128369at40674
# Downloaded 427 128441at40674
# Downloaded 428 128511at40674
# Downloaded 429 128533at40674
# Downloaded 430 128625at40674
# Downloaded 431 128629at40674
# Downloaded 432 128771at40674
# Downloaded 433 128863at40674
# Downloaded 434 12886at40674
# Downloaded 435 128871at40674
# Downloaded 436 128953at40674
# Downloaded 437 128978at40674
# Downloaded 438 128982at40674
# Downloaded 439 129004at40674
# Downloaded 440 129142at40674
# Downloaded 441 12917at40674
# Downloaded 442 129409at40674
# Downloaded 443 129411at40674
# Downloaded 444 129490at40674
# Downloaded 445 1294at40674
# Downloaded 446 129776at40674
# Downloaded 447 12994at40674
# Downloaded 448 12996at40674
# Downloaded 449 129998at40674
# Downloaded 450 130018at40674
# Downloaded 451 130115at40674
# Downloaded 452 130200at40674
# Downloaded 453 13025at40674
# Downloaded 454 130341at40674
# Downloaded 455 130627at40674
# Downloaded 456 130633at40674
# Downloaded 457 13075at40674
# Downloaded 458 130827at40674
# Downloaded 459 130857at40674
# Downloaded 460 130964at40674
# Downloaded 461 131096at40674
# Downloaded 462 131185at40674
# Downloaded 463 131238at40674
# Downloaded 464 131256at40674
# Downloaded 465 131346at40674
# Downloaded 466 131380at40674
# Downloaded 467 131404at40674
# Downloaded 468 13148at40674
# Downloaded 469 131579at40674
# Downloaded 470 13158at40674
# Downloaded 471 131594at40674
# Downloaded 472 131687at40674
# Downloaded 473 131719at40674
# Downloaded 474 13189at40674
# Downloaded 475 131900at40674
# Downloaded 476 13203at40674
# Downloaded 477 13206at40674
# Downloaded 478 13218at40674
# Downloaded 479 13220at40674
# Downloaded 480 132255at40674
# Downloaded 481 132358at40674
# Downloaded 482 132450at40674
# Downloaded 483 13258at40674
# Downloaded 484 132697at40674
# Downloaded 485 133004at40674
# Downloaded 486 133021at40674
# Downloaded 487 133049at40674
# Downloaded 488 133051at40674
# Downloaded 489 133059at40674
# Downloaded 490 1330at40674
# Downloaded 491 133184at40674
# Downloaded 492 1331at40674
# Downloaded 493 133312at40674
# Downloaded 494 133333at40674
# Downloaded 495 133360at40674
# Downloaded 496 133491at40674
# Downloaded 497 133542at40674
# Downloaded 498 133576at40674
# Downloaded 499 133808at40674
# Downloaded 500 133846at40674
# Scarico OG: 100%|██████████| 500/500 [03:42<00:00,  2.25og/s]

# %% [markdown]
# #### Basic cleaning
# Counting unique characters

# %%
fasta_dir = DATASET_ROOT / "orthodb_v12/raw"
patterns = ("*.fasta", "*.fa", "*.faa", "*.fna")

symbols = Counter()

for fasta_path in iter_fasta_files(fasta_dir, patterns=patterns):
    records = read_fasta(fasta_path)
    for _, seq in records:
        symbols.update(seq.upper())

# Remove empty key if present
if "" in symbols:
    del symbols[""]

print("Unique symbols found in sequences:")
print(" ".join(sorted(symbols.keys())))

print("\nCount per symbol:")

for sym, count in symbols.most_common():
    print(f"{sym!r}: {count}")
# Out:
# Unique symbols found in sequences:
# A C G K M N R S T W Y
#
# Count per symbol:
# 'G': 43172693
# 'C': 42636975
# 'A': 42447123
# 'T': 38339684
# 'N': 13590
# 'Y': 532
# 'R': 487
# 'M': 113
# 'S': 94
# 'K': 60
# 'W': 52

# %% [markdown]
# Resolve ambiguous bases, using the distribution of the certain ones

# %%
input_dir = DATASET_ROOT / "orthodb_v12/raw"
output_dir = DATASET_ROOT / "orthodb_v12/no_ambig_imp"
output_dir.mkdir(parents=True, exist_ok=True)

base_counts = {b : symbols[b] for b in "ACGT"}
total = sum(base_counts.values())
base_probs = {b : base_counts[b] / total for b in "ACGT"}

Path("global_base_probs.json").write_text(
    json.dumps(base_probs, indent=2)
)

print(f"Base counts: {base_counts}")
print(f"Total base counts: {total}")
print(f"Base probabilities: {base_probs}")

for in_path in tqdm(
        list(iter_fasta_files(
            input_dir,
            patterns=("*.fasta", "*.fa", "*.fna")
        )),
        desc="Resolving ambiguous bases",
        unit="file"
):
    out_path = output_dir / in_path.name

    records = read_fasta(in_path)
    sequences = [seq for _, seq in records]

    new_records = []
    for header, seq in records:
        new_seq = resolve_ambiguous_sequence(seq, base_probs)
        new_records.append((header, new_seq))

    write_fasta(out_path, new_records, width=60)

print("Done.")
# Out:
# Base counts: {'A': 42447123, 'C': 42636975, 'G': 43172693, 'T': 38339684}
# Total base counts: 166596475
# Base probabilities: {'A': 0.2547900428265364, 'C': 0.2559296347656816, 'G': 0.2591452970418492, 'T': 0.23013502536593286}
# Resolving ambiguous bases: 100%|██████████| 500/500 [00:11<00:00, 43.47file/s]
# Done.

# %% [markdown]
# Check for duplicate sequence

# %%
input_dir = DATASET_ROOT / "orthodb_v12/no_ambig_imp"

for path in iter_fasta_files(input_dir, patterns=("*.fasta", "*.fa", "*.fna", "*.faa", "*.cds.fasta")):
    records = read_fasta(path)
    duplicates = find_duplicate_sequences(records)

    print(f"\n=== {path.name} ===")
    if duplicates:
        print(f"Found {len(duplicates)} duplicated sequences:")
        for seq, count in duplicates.items():
            print(f" - occurrences: {count}")
    else:
        print("No duplicated sequences found.")
# Out:
# === 100009at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100011at40674.cds.fasta ===
# Found 57 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 14
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 8
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100068at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100125at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100128at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100187at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100244at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100287at40674.cds.fasta ===
# Found 31 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 8
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100314at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100670at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100672at40674.cds.fasta ===
# Found 15 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 100717at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 100729at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 3
#  - occurrences: 5
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100751at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100791at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100882at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 100969at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 100974at40674.cds.fasta ===
# Found 47 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 8
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10105at40674.cds.fasta ===
# Found 49 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 101211at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#
# === 101238at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 101254at40674.cds.fasta ===
# Found 24 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 101279at40674.cds.fasta ===
# Found 42 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 7
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 10129at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 101550at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 101553at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 101567at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102071at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102099at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102111at40674.cds.fasta ===
# Found 20 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 102314at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102321at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 102443at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 102455at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 102476at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10271at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102775at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 102791at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#
# === 102837at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 1030at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#
# === 103134at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 103140at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 103214at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 103249at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 103280at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 103294at40674.cds.fasta ===
# Found 13 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10332at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10333at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 103424at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 103430at40674.cds.fasta ===
# Found 41 duplicated sequences:
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 103472at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 103633at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 103647at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10367at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 103784at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10392at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104008at40674.cds.fasta ===
# Found 45 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 8
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 104048at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 1040at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10421at40674.cds.fasta ===
# Found 52 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10424at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104253at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104259at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10428at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104324at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 104505at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 104543at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10458at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 104764at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104826at40674.cds.fasta ===
# Found 43 duplicated sequences:
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 9
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 8
#  - occurrences: 7
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 11
#  - occurrences: 10
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 104941at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 104961at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105005at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105056at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 105076at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#
# === 105090at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105098at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105125at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10522at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105303at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105353at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105505at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105544at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105546at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105755at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105795at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#
# === 105796at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105862at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105918at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10597at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 105993at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 105at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 3
#
# === 106068at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 106081at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 106115at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 3
#
# === 106189at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10622at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#
# === 10636at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 10637at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 106619at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10667at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 106725at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10675at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 106787at40674.cds.fasta ===
# Found 26 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#
# === 106831at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 106840at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 106895at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#
# === 106975at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107045at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107054at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107168at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 10746at40674.cds.fasta ===
# Found 36 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 7
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 10750at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107523at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 107552at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#
# === 107623at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 107722at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 107756at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107812at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107884at40674.cds.fasta ===
# Found 13 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 107889at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 107972at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 108013at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108022at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 10805at40674.cds.fasta ===
# Found 18 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108141at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108142at40674.cds.fasta ===
# Found 15 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108147at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108331at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 108349at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 108396at40674.cds.fasta ===
# Found 13 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 10857at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 108615at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108780at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108809at40674.cds.fasta ===
# Found 14 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108820at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 10888at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 108900at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108911at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108995at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 108999at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109019at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109224at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 109347at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109408at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109518at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 109537at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109556at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 109578at40674.cds.fasta ===
# Found 29 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 3
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109660at40674.cds.fasta ===
# Found 20 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109689at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 109712at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 109796at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 109981at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 1101at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 110308at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 110340at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 110393at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 11049at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 110522at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 110554at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#
# === 110658at40674.cds.fasta ===
# Found 20 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 110747at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 1107at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 11092at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111008at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111081at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111125at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 3
#
# === 1112at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111325at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 111385at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 111412at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111420at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 11157at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111739at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111763at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 111842at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#
# === 11184at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 11191at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 111963at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#
# === 111985at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112035at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112070at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#
# === 112093at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112165at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112206at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 112253at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 112271at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 112326at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 112452at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112494at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 112496at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 3
#
# === 112532at40674.cds.fasta ===
# Found 19 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112608at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112657at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112672at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 112739at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 112896at40674.cds.fasta ===
# Found 19 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#
# === 112984at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 112988at40674.cds.fasta ===
# Found 27 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 11
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113020at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113022at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 11306at40674.cds.fasta ===
# Found 15 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113102at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#
# === 113225at40674.cds.fasta ===
# Found 27 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113333at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 11334at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 113390at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 113631at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 113664at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 113694at40674.cds.fasta ===
# Found 24 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113726at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 113730at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 113884at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#
# === 113940at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 1139at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 114024at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 114026at40674.cds.fasta ===
# Found 22 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 114209at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 114249at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 114256at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 114307at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 114510at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 114533at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 114640at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 114920at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 114989at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 115012at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115107at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115168at40674.cds.fasta ===
# Found 15 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115206at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115322at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 11543at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 11544at40674.cds.fasta ===
# Found 19 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 115472at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 115532at40674.cds.fasta ===
# Found 20 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 115537at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 115550at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 115605at40674.cds.fasta ===
# Found 13 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115842at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 115852at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 115878at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 115900at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116039at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116043at40674.cds.fasta ===
# Found 40 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116051at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 116068at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 1160at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 116110at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116134at40674.cds.fasta ===
# Found 17 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116166at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116204at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 116220at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 116375at40674.cds.fasta ===
# Found 18 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116452at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 116464at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 116487at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 116556at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#
# === 116580at40674.cds.fasta ===
# Found 5 duplicated sequences:
# ...
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 127309at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 127321at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 127360at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 127446at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 127495at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#
# === 127519at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 127604at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 127689at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 127784at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 127913at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 127924at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128064at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 128236at40674.cds.fasta ===
# Found 28 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128259at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128329at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128369at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128441at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128511at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128533at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128625at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128629at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 128771at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 128863at40674.cds.fasta ===
# Found 29 duplicated sequences:
#  - occurrences: 7
#  - occurrences: 11
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 9
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 12886at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 128871at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128953at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 3
#
# === 128978at40674.cds.fasta ===
# Found 17 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 128982at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 129004at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 129142at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 12917at40674.cds.fasta ===
# Found 30 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 5
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 129409at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 129411at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 129490at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#
# === 1294at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 129776at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 12994at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#
# === 12996at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 129998at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130018at40674.cds.fasta ===
# Found 29 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130115at40674.cds.fasta ===
# Found 19 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 130200at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 13025at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130341at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130627at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130633at40674.cds.fasta ===
# Found 16 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 13075at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 130827at40674.cds.fasta ===
# Found 13 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 7
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130857at40674.cds.fasta ===
# Found 7 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 130964at40674.cds.fasta ===
# Found 9 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 131096at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 131185at40674.cds.fasta ===
# Found 5 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 131238at40674.cds.fasta ===
# Found 4 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 131256at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 131346at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 131380at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 131404at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 13148at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 12
#  - occurrences: 4
#  - occurrences: 3
#  - occurrences: 2
#
# === 131579at40674.cds.fasta ===
# Found 2 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#
# === 13158at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 131594at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 131687at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 131719at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 13189at40674.cds.fasta ===
# Found 11 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 131900at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 13203at40674.cds.fasta ===
# Found 39 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 10
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 13206at40674.cds.fasta ===
# Found 22 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 18
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 31
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 6
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 5
#
# === 13218at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 13220at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 132255at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 132358at40674.cds.fasta ===
# Found 6 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#
# === 132450at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 13258at40674.cds.fasta ===
# Found 14 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 132697at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133004at40674.cds.fasta ===
# Found 50 duplicated sequences:
#  - occurrences: 6
#  - occurrences: 4
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 5
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#
# === 133021at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133049at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133051at40674.cds.fasta ===
# Found 10 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 133059at40674.cds.fasta ===
# Found 12 duplicated sequences:
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 3
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 1330at40674.cds.fasta ===
# Found 8 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 2
#
# === 133184at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 1331at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2
#
# === 133312at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133333at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133360at40674.cds.fasta ===
# Found 3 duplicated sequences:
#  - occurrences: 2
#  - occurrences: 2
#  - occurrences: 3
#
# === 133491at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133542at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133576at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133808at40674.cds.fasta ===
# No duplicated sequences found.
#
# === 133846at40674.cds.fasta ===
# Found 1 duplicated sequences:
#  - occurrences: 2

# %% [markdown]
# Remove duplicate sequences

# %%
input_dir = DATASET_ROOT / "orthodb_v12/no_ambig_imp"
output_dir = DATASET_ROOT / "orthodb_v12/unique_no_ambig_imp"
output_dir.mkdir(parents=True, exist_ok=True)

for in_path in iter_fasta_files(input_dir, patterns=("*.fasta", "*.fa", "*.faa", "*.fna", "*.cds.fasta")):
    records = read_fasta(in_path)
    out_records = make_unique_records(records)
    out_path = output_dir / in_path.name

    write_fasta(out_path, out_records)
    print(
        f"{in_path.name}: {len(records)} sequences → "
        f"{len(out_records)} unique sequences saved."
    )

print("\nDone.")
# Out:
# 100009at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 100011at40674.cds.fasta: 609 sequences → 503 unique sequences saved.
# 100068at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 100125at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 100128at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 100187at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 100244at40674.cds.fasta: 22 sequences → 22 unique sequences saved.
# 100287at40674.cds.fasta: 394 sequences → 330 unique sequences saved.
# 100314at40674.cds.fasta: 397 sequences → 391 unique sequences saved.
# 100670at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 100672at40674.cds.fasta: 409 sequences → 386 unique sequences saved.
# 100717at40674.cds.fasta: 402 sequences → 398 unique sequences saved.
# 100729at40674.cds.fasta: 143 sequences → 115 unique sequences saved.
# 100751at40674.cds.fasta: 132 sequences → 132 unique sequences saved.
# 100791at40674.cds.fasta: 314 sequences → 301 unique sequences saved.
# 100882at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 100969at40674.cds.fasta: 403 sequences → 386 unique sequences saved.
# 100974at40674.cds.fasta: 420 sequences → 329 unique sequences saved.
# 10105at40674.cds.fasta: 571 sequences → 499 unique sequences saved.
# 101211at40674.cds.fasta: 185 sequences → 180 unique sequences saved.
# 101238at40674.cds.fasta: 207 sequences → 200 unique sequences saved.
# 101254at40674.cds.fasta: 344 sequences → 307 unique sequences saved.
# 101279at40674.cds.fasta: 434 sequences → 367 unique sequences saved.
# 10129at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 101550at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 101553at40674.cds.fasta: 350 sequences → 336 unique sequences saved.
# 101567at40674.cds.fasta: 49 sequences → 49 unique sequences saved.
# 102071at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 102099at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 102111at40674.cds.fasta: 295 sequences → 268 unique sequences saved.
# 102314at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 102321at40674.cds.fasta: 388 sequences → 378 unique sequences saved.
# 102443at40674.cds.fasta: 403 sequences → 398 unique sequences saved.
# 102455at40674.cds.fasta: 11 sequences → 10 unique sequences saved.
# 102476at40674.cds.fasta: 15 sequences → 15 unique sequences saved.
# 10271at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 102775at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 102791at40674.cds.fasta: 241 sequences → 234 unique sequences saved.
# 102837at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 1030at40674.cds.fasta: 23 sequences → 21 unique sequences saved.
# 103134at40674.cds.fasta: 394 sequences → 381 unique sequences saved.
# 103140at40674.cds.fasta: 6 sequences → 5 unique sequences saved.
# 103214at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 103249at40674.cds.fasta: 499 sequences → 487 unique sequences saved.
# 103280at40674.cds.fasta: 25 sequences → 25 unique sequences saved.
# 103294at40674.cds.fasta: 394 sequences → 378 unique sequences saved.
# 10332at40674.cds.fasta: 430 sequences → 420 unique sequences saved.
# 10333at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 103424at40674.cds.fasta: 154 sequences → 154 unique sequences saved.
# 103430at40674.cds.fasta: 473 sequences → 414 unique sequences saved.
# 103472at40674.cds.fasta: 51 sequences → 51 unique sequences saved.
# 103633at40674.cds.fasta: 561 sequences → 546 unique sequences saved.
# 103647at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 10367at40674.cds.fasta: 292 sequences → 291 unique sequences saved.
# 103784at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 10392at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 104008at40674.cds.fasta: 420 sequences → 341 unique sequences saved.
# 104048at40674.cds.fasta: 210 sequences → 201 unique sequences saved.
# 1040at40674.cds.fasta: 14 sequences → 14 unique sequences saved.
# 10421at40674.cds.fasta: 853 sequences → 781 unique sequences saved.
# 10424at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 104253at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 104259at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 10428at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 104324at40674.cds.fasta: 7 sequences → 6 unique sequences saved.
# 104505at40674.cds.fasta: 391 sequences → 386 unique sequences saved.
# 104543at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 10458at40674.cds.fasta: 402 sequences → 386 unique sequences saved.
# 104764at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 104826at40674.cds.fasta: 414 sequences → 307 unique sequences saved.
# 104941at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 104961at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 105005at40674.cds.fasta: 403 sequences → 391 unique sequences saved.
# 105056at40674.cds.fasta: 228 sequences → 222 unique sequences saved.
# 105076at40674.cds.fasta: 54 sequences → 49 unique sequences saved.
# 105090at40674.cds.fasta: 371 sequences → 368 unique sequences saved.
# 105098at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 105125at40674.cds.fasta: 47 sequences → 40 unique sequences saved.
# 10522at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 105303at40674.cds.fasta: 21 sequences → 21 unique sequences saved.
# 105353at40674.cds.fasta: 26 sequences → 26 unique sequences saved.
# 105505at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 105544at40674.cds.fasta: 445 sequences → 431 unique sequences saved.
# 105546at40674.cds.fasta: 21 sequences → 21 unique sequences saved.
# 105755at40674.cds.fasta: 419 sequences → 412 unique sequences saved.
# 105795at40674.cds.fasta: 28 sequences → 22 unique sequences saved.
# 105796at40674.cds.fasta: 14 sequences → 14 unique sequences saved.
# 105862at40674.cds.fasta: 404 sequences → 396 unique sequences saved.
# 105918at40674.cds.fasta: 15 sequences → 15 unique sequences saved.
# 10597at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 105993at40674.cds.fasta: 12 sequences → 8 unique sequences saved.
# 105at40674.cds.fasta: 35 sequences → 33 unique sequences saved.
# 106068at40674.cds.fasta: 306 sequences → 295 unique sequences saved.
# 106081at40674.cds.fasta: 408 sequences → 402 unique sequences saved.
# 106115at40674.cds.fasta: 6 sequences → 4 unique sequences saved.
# 106189at40674.cds.fasta: 197 sequences → 184 unique sequences saved.
# 10622at40674.cds.fasta: 272 sequences → 267 unique sequences saved.
# 10636at40674.cds.fasta: 47 sequences → 46 unique sequences saved.
# 10637at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 106619at40674.cds.fasta: 383 sequences → 375 unique sequences saved.
# 10667at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 106725at40674.cds.fasta: 394 sequences → 387 unique sequences saved.
# 10675at40674.cds.fasta: 32 sequences → 32 unique sequences saved.
# 106787at40674.cds.fasta: 418 sequences → 387 unique sequences saved.
# 106831at40674.cds.fasta: 291 sequences → 286 unique sequences saved.
# 106840at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 106895at40674.cds.fasta: 366 sequences → 360 unique sequences saved.
# 106975at40674.cds.fasta: 408 sequences → 388 unique sequences saved.
# 107045at40674.cds.fasta: 403 sequences → 384 unique sequences saved.
# 107054at40674.cds.fasta: 409 sequences → 396 unique sequences saved.
# 107168at40674.cds.fasta: 7 sequences → 6 unique sequences saved.
# 10746at40674.cds.fasta: 401 sequences → 341 unique sequences saved.
# 10750at40674.cds.fasta: 382 sequences → 373 unique sequences saved.
# 107523at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 107552at40674.cds.fasta: 103 sequences → 99 unique sequences saved.
# 107623at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 107722at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 107756at40674.cds.fasta: 154 sequences → 150 unique sequences saved.
# 107812at40674.cds.fasta: 418 sequences → 414 unique sequences saved.
# 107884at40674.cds.fasta: 400 sequences → 387 unique sequences saved.
# 107889at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 107972at40674.cds.fasta: 10 sequences → 9 unique sequences saved.
# 108013at40674.cds.fasta: 390 sequences → 382 unique sequences saved.
# 108022at40674.cds.fasta: 37 sequences → 27 unique sequences saved.
# 10805at40674.cds.fasta: 391 sequences → 370 unique sequences saved.
# 108141at40674.cds.fasta: 286 sequences → 279 unique sequences saved.
# 108142at40674.cds.fasta: 411 sequences → 394 unique sequences saved.
# 108147at40674.cds.fasta: 403 sequences → 400 unique sequences saved.
# 108331at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 108349at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 108396at40674.cds.fasta: 401 sequences → 386 unique sequences saved.
# 10857at40674.cds.fasta: 280 sequences → 275 unique sequences saved.
# 108615at40674.cds.fasta: 429 sequences → 418 unique sequences saved.
# 108780at40674.cds.fasta: 420 sequences → 393 unique sequences saved.
# 108809at40674.cds.fasta: 427 sequences → 413 unique sequences saved.
# 108820at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 10888at40674.cds.fasta: 8 sequences → 7 unique sequences saved.
# 108900at40674.cds.fasta: 276 sequences → 271 unique sequences saved.
# 108911at40674.cds.fasta: 318 sequences → 314 unique sequences saved.
# 108995at40674.cds.fasta: 404 sequences → 398 unique sequences saved.
# 108999at40674.cds.fasta: 404 sequences → 395 unique sequences saved.
# 109019at40674.cds.fasta: 402 sequences → 389 unique sequences saved.
# 109224at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 109347at40674.cds.fasta: 405 sequences → 395 unique sequences saved.
# 109408at40674.cds.fasta: 394 sequences → 390 unique sequences saved.
# 109518at40674.cds.fasta: 404 sequences → 397 unique sequences saved.
# 109537at40674.cds.fasta: 412 sequences → 406 unique sequences saved.
# 109556at40674.cds.fasta: 435 sequences → 428 unique sequences saved.
# 109578at40674.cds.fasta: 402 sequences → 358 unique sequences saved.
# 109660at40674.cds.fasta: 476 sequences → 450 unique sequences saved.
# 109689at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 109712at40674.cds.fasta: 372 sequences → 359 unique sequences saved.
# 109796at40674.cds.fasta: 402 sequences → 389 unique sequences saved.
# 109981at40674.cds.fasta: 394 sequences → 384 unique sequences saved.
# 1101at40674.cds.fasta: 137 sequences → 136 unique sequences saved.
# 110308at40674.cds.fasta: 404 sequences → 397 unique sequences saved.
# 110340at40674.cds.fasta: 411 sequences → 399 unique sequences saved.
# 110393at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 11049at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 110522at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 110554at40674.cds.fasta: 229 sequences → 217 unique sequences saved.
# 110658at40674.cds.fasta: 401 sequences → 370 unique sequences saved.
# 110747at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 1107at40674.cds.fasta: 409 sequences → 386 unique sequences saved.
# 11092at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 111008at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 111081at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 111125at40674.cds.fasta: 20 sequences → 18 unique sequences saved.
# 1112at40674.cds.fasta: 25 sequences → 25 unique sequences saved.
# 111325at40674.cds.fasta: 420 sequences → 410 unique sequences saved.
# 111385at40674.cds.fasta: 386 sequences → 372 unique sequences saved.
# 111412at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 111420at40674.cds.fasta: 400 sequences → 397 unique sequences saved.
# 11157at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 111739at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 111763at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 111842at40674.cds.fasta: 406 sequences → 404 unique sequences saved.
# 11184at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 11191at40674.cds.fasta: 390 sequences → 384 unique sequences saved.
# 111963at40674.cds.fasta: 72 sequences → 70 unique sequences saved.
# 111985at40674.cds.fasta: 183 sequences → 178 unique sequences saved.
# 112035at40674.cds.fasta: 504 sequences → 499 unique sequences saved.
# 112070at40674.cds.fasta: 404 sequences → 401 unique sequences saved.
# 112093at40674.cds.fasta: 407 sequences → 402 unique sequences saved.
# 112165at40674.cds.fasta: 367 sequences → 360 unique sequences saved.
# 112206at40674.cds.fasta: 220 sequences → 211 unique sequences saved.
# 112253at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 112271at40674.cds.fasta: 44 sequences → 44 unique sequences saved.
# 112326at40674.cds.fasta: 403 sequences → 397 unique sequences saved.
# 112452at40674.cds.fasta: 243 sequences → 239 unique sequences saved.
# 112494at40674.cds.fasta: 43 sequences → 43 unique sequences saved.
# 112496at40674.cds.fasta: 53 sequences → 51 unique sequences saved.
# 112532at40674.cds.fasta: 384 sequences → 357 unique sequences saved.
# 112608at40674.cds.fasta: 393 sequences → 389 unique sequences saved.
# 112657at40674.cds.fasta: 412 sequences → 408 unique sequences saved.
# 112672at40674.cds.fasta: 30 sequences → 30 unique sequences saved.
# 112739at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 112896at40674.cds.fasta: 687 sequences → 661 unique sequences saved.
# 112984at40674.cds.fasta: 405 sequences → 393 unique sequences saved.
# 112988at40674.cds.fasta: 410 sequences → 367 unique sequences saved.
# 113020at40674.cds.fasta: 416 sequences → 403 unique sequences saved.
# 113022at40674.cds.fasta: 370 sequences → 348 unique sequences saved.
# 11306at40674.cds.fasta: 383 sequences → 364 unique sequences saved.
# 113102at40674.cds.fasta: 303 sequences → 300 unique sequences saved.
# 113225at40674.cds.fasta: 403 sequences → 364 unique sequences saved.
# 113333at40674.cds.fasta: 457 sequences → 456 unique sequences saved.
# 11334at40674.cds.fasta: 15 sequences → 15 unique sequences saved.
# 113390at40674.cds.fasta: 35 sequences → 35 unique sequences saved.
# 113631at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 113664at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 113694at40674.cds.fasta: 456 sequences → 417 unique sequences saved.
# 113726at40674.cds.fasta: 217 sequences → 211 unique sequences saved.
# 113730at40674.cds.fasta: 378 sequences → 370 unique sequences saved.
# 113884at40674.cds.fasta: 401 sequences → 398 unique sequences saved.
# 113940at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 1139at40674.cds.fasta: 410 sequences → 403 unique sequences saved.
# 114024at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 114026at40674.cds.fasta: 398 sequences → 370 unique sequences saved.
# 114209at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 114249at40674.cds.fasta: 10 sequences → 9 unique sequences saved.
# 114256at40674.cds.fasta: 15 sequences → 15 unique sequences saved.
# 114307at40674.cds.fasta: 401 sequences → 395 unique sequences saved.
# 114510at40674.cds.fasta: 404 sequences → 396 unique sequences saved.
# 114533at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 114640at40674.cds.fasta: 35 sequences → 35 unique sequences saved.
# 114920at40674.cds.fasta: 403 sequences → 397 unique sequences saved.
# 114989at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 115012at40674.cds.fasta: 408 sequences → 405 unique sequences saved.
# 115107at40674.cds.fasta: 406 sequences → 399 unique sequences saved.
# 115168at40674.cds.fasta: 799 sequences → 783 unique sequences saved.
# 115206at40674.cds.fasta: 412 sequences → 406 unique sequences saved.
# 115322at40674.cds.fasta: 400 sequences → 395 unique sequences saved.
# 11543at40674.cds.fasta: 403 sequences → 394 unique sequences saved.
# 11544at40674.cds.fasta: 410 sequences → 385 unique sequences saved.
# 115472at40674.cds.fasta: 112 sequences → 112 unique sequences saved.
# 115532at40674.cds.fasta: 409 sequences → 382 unique sequences saved.
# 115537at40674.cds.fasta: 209 sequences → 203 unique sequences saved.
# 115550at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 115605at40674.cds.fasta: 404 sequences → 391 unique sequences saved.
# 115842at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 115852at40674.cds.fasta: 408 sequences → 397 unique sequences saved.
# 115878at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 115900at40674.cds.fasta: 400 sequences → 384 unique sequences saved.
# 116039at40674.cds.fasta: 406 sequences → 396 unique sequences saved.
# 116043at40674.cds.fasta: 916 sequences → 868 unique sequences saved.
# 116051at40674.cds.fasta: 11 sequences → 11 unique sequences saved.
# 116068at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 1160at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 116110at40674.cds.fasta: 402 sequences → 399 unique sequences saved.
# 116134at40674.cds.fasta: 674 sequences → 650 unique sequences saved.
# 116166at40674.cds.fasta: 400 sequences → 391 unique sequences saved.
# 116204at40674.cds.fasta: 305 sequences → 305 unique sequences saved.
# 116220at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 116375at40674.cds.fasta: 387 sequences → 357 unique sequences saved.
# 116452at40674.cds.fasta: 269 sequences → 246 unique sequences saved.
# 116464at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 116487at40674.cds.fasta: 77 sequences → 76 unique sequences saved.
# 116556at40674.cds.fasta: 404 sequences → 394 unique sequences saved.
# 116580at40674.cds.fasta: 252 sequences → 247 unique sequences saved.
# 116638at40674.cds.fasta: 404 sequences → 377 unique sequences saved.
# 116678at40674.cds.fasta: 400 sequences → 391 unique sequences saved.
# 116742at40674.cds.fasta: 3 sequences → 2 unique sequences saved.
# 11692at40674.cds.fasta: 399 sequences → 390 unique sequences saved.
# 116948at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 116968at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 117072at40674.cds.fasta: 22 sequences → 22 unique sequences saved.
# 11717at40674.cds.fasta: 397 sequences → 381 unique sequences saved.
# 117224at40674.cds.fasta: 13 sequences → 13 unique sequences saved.
# 117386at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 117391at40674.cds.fasta: 410 sequences → 397 unique sequences saved.
# 117406at40674.cds.fasta: 117 sequences → 113 unique sequences saved.
# 117590at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 11763at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 11774at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 117759at40674.cds.fasta: 428 sequences → 420 unique sequences saved.
# 117938at40674.cds.fasta: 408 sequences → 403 unique sequences saved.
# 118032at40674.cds.fasta: 399 sequences → 399 unique sequences saved.
# 118064at40674.cds.fasta: 406 sequences → 384 unique sequences saved.
# 118078at40674.cds.fasta: 417 sequences → 399 unique sequences saved.
# 118113at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 118174at40674.cds.fasta: 441 sequences → 425 unique sequences saved.
# 118192at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 118231at40674.cds.fasta: 408 sequences → 402 unique sequences saved.
# 118246at40674.cds.fasta: 449 sequences → 440 unique sequences saved.
# 118348at40674.cds.fasta: 405 sequences → 381 unique sequences saved.
# 118591at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 118616at40674.cds.fasta: 9 sequences → 9 unique sequences saved.
# 118708at40674.cds.fasta: 145 sequences → 143 unique sequences saved.
# 118714at40674.cds.fasta: 344 sequences → 299 unique sequences saved.
# 118798at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 118827at40674.cds.fasta: 417 sequences → 408 unique sequences saved.
# 118914at40674.cds.fasta: 419 sequences → 406 unique sequences saved.
# 118968at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 119116at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 119248at40674.cds.fasta: 10 sequences → 9 unique sequences saved.
# 11931at40674.cds.fasta: 13 sequences → 13 unique sequences saved.
# 119366at40674.cds.fasta: 415 sequences → 409 unique sequences saved.
# 119414at40674.cds.fasta: 406 sequences → 395 unique sequences saved.
# 119458at40674.cds.fasta: 407 sequences → 400 unique sequences saved.
# 119481at40674.cds.fasta: 281 sequences → 275 unique sequences saved.
# 119589at40674.cds.fasta: 587 sequences → 540 unique sequences saved.
# 11964at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 119848at40674.cds.fasta: 409 sequences → 400 unique sequences saved.
# 119863at40674.cds.fasta: 543 sequences → 406 unique sequences saved.
# 119894at40674.cds.fasta: 225 sequences → 222 unique sequences saved.
# 119929at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 120046at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 120122at40674.cds.fasta: 8 sequences → 7 unique sequences saved.
# 120140at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 12019at40674.cds.fasta: 225 sequences → 222 unique sequences saved.
# 120376at40674.cds.fasta: 401 sequences → 390 unique sequences saved.
# 120397at40674.cds.fasta: 415 sequences → 400 unique sequences saved.
# 120467at40674.cds.fasta: 137 sequences → 131 unique sequences saved.
# 120584at40674.cds.fasta: 437 sequences → 383 unique sequences saved.
# 120635at40674.cds.fasta: 403 sequences → 401 unique sequences saved.
# 12071at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 120746at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 120868at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 120915at40674.cds.fasta: 8 sequences → 7 unique sequences saved.
# 120917at40674.cds.fasta: 401 sequences → 391 unique sequences saved.
# 120919at40674.cds.fasta: 410 sequences → 395 unique sequences saved.
# 121005at40674.cds.fasta: 404 sequences → 389 unique sequences saved.
# 121035at40674.cds.fasta: 395 sequences → 371 unique sequences saved.
# 12110at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 121118at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 121361at40674.cds.fasta: 146 sequences → 144 unique sequences saved.
# 121383at40674.cds.fasta: 508 sequences → 471 unique sequences saved.
# 121425at40674.cds.fasta: 13 sequences → 11 unique sequences saved.
# 121650at40674.cds.fasta: 42 sequences → 36 unique sequences saved.
# 12170at40674.cds.fasta: 26 sequences → 26 unique sequences saved.
# 121740at40674.cds.fasta: 72 sequences → 69 unique sequences saved.
# 121754at40674.cds.fasta: 328 sequences → 324 unique sequences saved.
# 12175at40674.cds.fasta: 408 sequences → 402 unique sequences saved.
# 12190at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 121989at40674.cds.fasta: 409 sequences → 404 unique sequences saved.
# 122026at40674.cds.fasta: 115 sequences → 111 unique sequences saved.
# 122326at40674.cds.fasta: 404 sequences → 401 unique sequences saved.
# 122375at40674.cds.fasta: 31 sequences → 31 unique sequences saved.
# 122406at40674.cds.fasta: 435 sequences → 411 unique sequences saved.
# 122429at40674.cds.fasta: 392 sequences → 386 unique sequences saved.
# 122502at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 122504at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 122506at40674.cds.fasta: 5 sequences → 4 unique sequences saved.
# 122605at40674.cds.fasta: 821 sequences → 710 unique sequences saved.
# 122634at40674.cds.fasta: 405 sequences → 387 unique sequences saved.
# 122646at40674.cds.fasta: 408 sequences → 388 unique sequences saved.
# 122883at40674.cds.fasta: 90 sequences → 90 unique sequences saved.
# 12296at40674.cds.fasta: 506 sequences → 493 unique sequences saved.
# 123260at40674.cds.fasta: 264 sequences → 256 unique sequences saved.
# 123317at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 12359at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 12361at40674.cds.fasta: 529 sequences → 475 unique sequences saved.
# 123691at40674.cds.fasta: 260 sequences → 249 unique sequences saved.
# 1236at40674.cds.fasta: 430 sequences → 419 unique sequences saved.
# 123715at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 123748at40674.cds.fasta: 302 sequences → 294 unique sequences saved.
# 123812at40674.cds.fasta: 29 sequences → 29 unique sequences saved.
# 123844at40674.cds.fasta: 395 sequences → 379 unique sequences saved.
# 123854at40674.cds.fasta: 437 sequences → 434 unique sequences saved.
# 123891at40674.cds.fasta: 50 sequences → 48 unique sequences saved.
# 123934at40674.cds.fasta: 225 sequences → 223 unique sequences saved.
# 123945at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 123968at40674.cds.fasta: 404 sequences → 392 unique sequences saved.
# 123994at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 124016at40674.cds.fasta: 11 sequences → 11 unique sequences saved.
# 124024at40674.cds.fasta: 126 sequences → 125 unique sequences saved.
# 12419at40674.cds.fasta: 364 sequences → 359 unique sequences saved.
# 124223at40674.cds.fasta: 412 sequences → 400 unique sequences saved.
# 12424at40674.cds.fasta: 404 sequences → 388 unique sequences saved.
# 124251at40674.cds.fasta: 9 sequences → 7 unique sequences saved.
# 124255at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 124297at40674.cds.fasta: 400 sequences → 395 unique sequences saved.
# 124302at40674.cds.fasta: 383 sequences → 380 unique sequences saved.
# 124453at40674.cds.fasta: 404 sequences → 400 unique sequences saved.
# 124471at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 124546at40674.cds.fasta: 408 sequences → 402 unique sequences saved.
# 124635at40674.cds.fasta: 402 sequences → 394 unique sequences saved.
# 124652at40674.cds.fasta: 407 sequences → 382 unique sequences saved.
# 124688at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 124761at40674.cds.fasta: 390 sequences → 378 unique sequences saved.
# 124900at40674.cds.fasta: 17 sequences → 17 unique sequences saved.
# 124940at40674.cds.fasta: 235 sequences → 219 unique sequences saved.
# 125054at40674.cds.fasta: 399 sequences → 394 unique sequences saved.
# 12514at40674.cds.fasta: 26 sequences → 23 unique sequences saved.
# 125158at40674.cds.fasta: 402 sequences → 397 unique sequences saved.
# 125227at40674.cds.fasta: 24 sequences → 24 unique sequences saved.
# 125319at40674.cds.fasta: 403 sequences → 356 unique sequences saved.
# 12540at40674.cds.fasta: 412 sequences → 394 unique sequences saved.
# 125428at40674.cds.fasta: 418 sequences → 392 unique sequences saved.
# 125469at40674.cds.fasta: 11 sequences → 8 unique sequences saved.
# 125529at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 12562at40674.cds.fasta: 397 sequences → 393 unique sequences saved.
# 125697at40674.cds.fasta: 417 sequences → 382 unique sequences saved.
# 125904at40674.cds.fasta: 411 sequences → 373 unique sequences saved.
# 12593at40674.cds.fasta: 22 sequences → 22 unique sequences saved.
# 125946at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 126018at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 12605at40674.cds.fasta: 445 sequences → 393 unique sequences saved.
# 126308at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 126375at40674.cds.fasta: 393 sequences → 384 unique sequences saved.
# 126770at40674.cds.fasta: 3 sequences → 2 unique sequences saved.
# 126805at40674.cds.fasta: 405 sequences → 396 unique sequences saved.
# 126849at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 12688at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 126968at40674.cds.fasta: 14 sequences → 14 unique sequences saved.
# 12699at40674.cds.fasta: 35 sequences → 35 unique sequences saved.
# 127013at40674.cds.fasta: 391 sequences → 387 unique sequences saved.
# 127055at40674.cds.fasta: 405 sequences → 380 unique sequences saved.
# 127189at40674.cds.fasta: 404 sequences → 385 unique sequences saved.
# 12726at40674.cds.fasta: 336 sequences → 322 unique sequences saved.
# 127309at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 127321at40674.cds.fasta: 406 sequences → 400 unique sequences saved.
# 127360at40674.cds.fasta: 399 sequences → 393 unique sequences saved.
# 127446at40674.cds.fasta: 403 sequences → 395 unique sequences saved.
# 127495at40674.cds.fasta: 165 sequences → 163 unique sequences saved.
# 127519at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 127604at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 127689at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 127784at40674.cds.fasta: 379 sequences → 374 unique sequences saved.
# 127913at40674.cds.fasta: 426 sequences → 420 unique sequences saved.
# 127924at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 128064at40674.cds.fasta: 391 sequences → 383 unique sequences saved.
# 128236at40674.cds.fasta: 807 sequences → 770 unique sequences saved.
# 128259at40674.cds.fasta: 52 sequences → 52 unique sequences saved.
# 128329at40674.cds.fasta: 400 sequences → 387 unique sequences saved.
# 128369at40674.cds.fasta: 411 sequences → 401 unique sequences saved.
# 128441at40674.cds.fasta: 924 sequences → 916 unique sequences saved.
# 128511at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 128533at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 128625at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 128629at40674.cds.fasta: 402 sequences → 392 unique sequences saved.
# 128771at40674.cds.fasta: 403 sequences → 393 unique sequences saved.
# 128863at40674.cds.fasta: 403 sequences → 342 unique sequences saved.
# 12886at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 128871at40674.cds.fasta: 402 sequences → 395 unique sequences saved.
# 128953at40674.cds.fasta: 25 sequences → 23 unique sequences saved.
# 128978at40674.cds.fasta: 630 sequences → 603 unique sequences saved.
# 128982at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 129004at40674.cds.fasta: 407 sequences → 399 unique sequences saved.
# 129142at40674.cds.fasta: 16 sequences → 16 unique sequences saved.
# 12917at40674.cds.fasta: 409 sequences → 363 unique sequences saved.
# 129409at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 129411at40674.cds.fasta: 12 sequences → 12 unique sequences saved.
# 129490at40674.cds.fasta: 10 sequences → 8 unique sequences saved.
# 1294at40674.cds.fasta: 405 sequences → 394 unique sequences saved.
# 129776at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 12994at40674.cds.fasta: 406 sequences → 401 unique sequences saved.
# 12996at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 129998at40674.cds.fasta: 406 sequences → 401 unique sequences saved.
# 130018at40674.cds.fasta: 467 sequences → 433 unique sequences saved.
# 130115at40674.cds.fasta: 553 sequences → 530 unique sequences saved.
# 130200at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 13025at40674.cds.fasta: 362 sequences → 340 unique sequences saved.
# 130341at40674.cds.fasta: 318 sequences → 306 unique sequences saved.
# 130627at40674.cds.fasta: 390 sequences → 383 unique sequences saved.
# 130633at40674.cds.fasta: 411 sequences → 393 unique sequences saved.
# 13075at40674.cds.fasta: 21 sequences → 21 unique sequences saved.
# 130827at40674.cds.fasta: 179 sequences → 157 unique sequences saved.
# 130857at40674.cds.fasta: 422 sequences → 414 unique sequences saved.
# 130964at40674.cds.fasta: 406 sequences → 397 unique sequences saved.
# 131096at40674.cds.fasta: 10 sequences → 10 unique sequences saved.
# 131185at40674.cds.fasta: 543 sequences → 538 unique sequences saved.
# 131238at40674.cds.fasta: 408 sequences → 404 unique sequences saved.
# 131256at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 131346at40674.cds.fasta: 423 sequences → 412 unique sequences saved.
# 131380at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 131404at40674.cds.fasta: 442 sequences → 430 unique sequences saved.
# 13148at40674.cds.fasta: 83 sequences → 55 unique sequences saved.
# 131579at40674.cds.fasta: 61 sequences → 58 unique sequences saved.
# 13158at40674.cds.fasta: 406 sequences → 402 unique sequences saved.
# 131594at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 131687at40674.cds.fasta: 119 sequences → 119 unique sequences saved.
# 131719at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 13189at40674.cds.fasta: 507 sequences → 495 unique sequences saved.
# 131900at40674.cds.fasta: 15 sequences → 14 unique sequences saved.
# 13203at40674.cds.fasta: 452 sequences → 380 unique sequences saved.
# 13206at40674.cds.fasta: 235 sequences → 151 unique sequences saved.
# 13218at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 13220at40674.cds.fasta: 8 sequences → 8 unique sequences saved.
# 132255at40674.cds.fasta: 14 sequences → 13 unique sequences saved.
# 132358at40674.cds.fasta: 418 sequences → 411 unique sequences saved.
# 132450at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 13258at40674.cds.fasta: 410 sequences → 394 unique sequences saved.
# 132697at40674.cds.fasta: 7 sequences → 7 unique sequences saved.
# 133004at40674.cds.fasta: 1545 sequences → 1481 unique sequences saved.
# 133021at40674.cds.fasta: 61 sequences → 61 unique sequences saved.
# 133049at40674.cds.fasta: 122 sequences → 122 unique sequences saved.
# 133051at40674.cds.fasta: 402 sequences → 390 unique sequences saved.
# 133059at40674.cds.fasta: 411 sequences → 396 unique sequences saved.
# 1330at40674.cds.fasta: 389 sequences → 381 unique sequences saved.
# 133184at40674.cds.fasta: 5 sequences → 5 unique sequences saved.
# 1331at40674.cds.fasta: 6 sequences → 5 unique sequences saved.
# 133312at40674.cds.fasta: 3 sequences → 3 unique sequences saved.
# 133333at40674.cds.fasta: 28 sequences → 28 unique sequences saved.
# 133360at40674.cds.fasta: 419 sequences → 415 unique sequences saved.
# 133491at40674.cds.fasta: 6 sequences → 6 unique sequences saved.
# 133542at40674.cds.fasta: 19 sequences → 19 unique sequences saved.
# 133576at40674.cds.fasta: 4 sequences → 4 unique sequences saved.
# 133808at40674.cds.fasta: 20 sequences → 20 unique sequences saved.
# 133846at40674.cds.fasta: 55 sequences → 54 unique sequences saved.
#
# Done.

# %% [markdown]
# Optionally cut sequences longer than K to a random length included in [K-H, K]

# %%
IN_DIR = DATASET_ROOT / "orthodb_v12/unique_no_ambig_imp"
OUT_DIR = DATASET_ROOT / "orthodb_v12/unique_no_ambig_imp_cut"
OUT_DIR.mkdir(parents=True, exist_ok=True)

K = 300   # threshold: sequences longer than K will be cut
H = 100   # interval: new length will be in [K-H, K]


def process_file(fin: Path):
    records = read_fasta(fin)
    if not records:
        return

    new_records = []
    lengths_before = []
    lengths_after = []

    for h, s in records:
        orig_len = len(s)
        new_len = random_cut_length(orig_len, K=K, H=H)
        new_s = s[:new_len]
        new_records.append((h, new_s))
        lengths_before.append(orig_len)
        lengths_after.append(new_len)

    fout = OUT_DIR / fin.name
    write_fasta(fout, new_records, width=WRAP_DEFAULT)

    print(
        f"{fin.name} -> {fout} | nseq={len(records)} | "
        f"len_before=[{min(lengths_before)}–{max(lengths_before)}] | "
        f"len_after=[{min(lengths_after)}–{max(lengths_after)}]"
    )


for fin in iter_fasta_files(IN_DIR, patterns=("*.fasta", "*.fa", "*.fna", "*.cds.fasta")):
    process_file(fin)

print("Done.")
# Out:
# 100009at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100009at40674.cds.fasta | nseq=6 | len_before=[276–453] | len_after=[253–298]
# 100011at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100011at40674.cds.fasta | nseq=503 | len_before=[192–864] | len_after=[192–300]
# 100068at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100068at40674.cds.fasta | nseq=9 | len_before=[303–987] | len_after=[219–286]
# 100125at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100125at40674.cds.fasta | nseq=7 | len_before=[465–807] | len_after=[204–299]
# 100128at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100128at40674.cds.fasta | nseq=3 | len_before=[312–312] | len_after=[206–263]
# 100187at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100187at40674.cds.fasta | nseq=7 | len_before=[360–480] | len_after=[200–299]
# 100244at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100244at40674.cds.fasta | nseq=22 | len_before=[828–1215] | len_after=[201–295]
# 100287at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100287at40674.cds.fasta | nseq=330 | len_before=[168–1725] | len_after=[168–299]
# 100314at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100314at40674.cds.fasta | nseq=391 | len_before=[348–2052] | len_after=[201–300]
# 100670at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100670at40674.cds.fasta | nseq=20 | len_before=[207–609] | len_after=[207–298]
# 100672at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100672at40674.cds.fasta | nseq=386 | len_before=[468–2058] | len_after=[200–300]
# 100717at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100717at40674.cds.fasta | nseq=398 | len_before=[321–3270] | len_after=[200–300]
# 100729at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100729at40674.cds.fasta | nseq=115 | len_before=[189–414] | len_after=[189–291]
# 100751at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100751at40674.cds.fasta | nseq=132 | len_before=[152–903] | len_after=[152–300]
# 100791at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100791at40674.cds.fasta | nseq=301 | len_before=[261–1893] | len_after=[200–300]
# 100882at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100882at40674.cds.fasta | nseq=4 | len_before=[255–375] | len_after=[255–282]
# 100969at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100969at40674.cds.fasta | nseq=386 | len_before=[411–1863] | len_after=[200–300]
# 100974at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\100974at40674.cds.fasta | nseq=329 | len_before=[228–843] | len_after=[201–300]
# 10105at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10105at40674.cds.fasta | nseq=499 | len_before=[180–552] | len_after=[180–300]
# 101211at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101211at40674.cds.fasta | nseq=180 | len_before=[270–2829] | len_after=[200–300]
# 101238at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101238at40674.cds.fasta | nseq=200 | len_before=[204–825] | len_after=[201–300]
# 101254at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101254at40674.cds.fasta | nseq=307 | len_before=[390–999] | len_after=[200–300]
# 101279at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101279at40674.cds.fasta | nseq=367 | len_before=[243–618] | len_after=[200–300]
# 10129at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10129at40674.cds.fasta | nseq=7 | len_before=[555–627] | len_after=[217–294]
# 101550at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101550at40674.cds.fasta | nseq=8 | len_before=[537–702] | len_after=[202–283]
# 101553at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101553at40674.cds.fasta | nseq=336 | len_before=[198–1626] | len_after=[198–300]
# 101567at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\101567at40674.cds.fasta | nseq=49 | len_before=[831–1548] | len_after=[203–292]
# 102071at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102071at40674.cds.fasta | nseq=6 | len_before=[546–555] | len_after=[219–300]
# 102099at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102099at40674.cds.fasta | nseq=5 | len_before=[387–966] | len_after=[217–295]
# 102111at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102111at40674.cds.fasta | nseq=268 | len_before=[207–903] | len_after=[200–300]
# 102314at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102314at40674.cds.fasta | nseq=5 | len_before=[825–1005] | len_after=[202–263]
# 102321at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102321at40674.cds.fasta | nseq=378 | len_before=[273–1707] | len_after=[200–300]
# 102443at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102443at40674.cds.fasta | nseq=398 | len_before=[2766–4389] | len_after=[200–300]
# 102455at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102455at40674.cds.fasta | nseq=10 | len_before=[225–1497] | len_after=[213–276]
# 102476at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102476at40674.cds.fasta | nseq=15 | len_before=[321–955] | len_after=[201–290]
# 10271at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10271at40674.cds.fasta | nseq=10 | len_before=[297–495] | len_after=[207–297]
# 102775at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102775at40674.cds.fasta | nseq=3 | len_before=[423–423] | len_after=[200–266]
# 102791at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102791at40674.cds.fasta | nseq=234 | len_before=[258–1317] | len_after=[200–300]
# 102837at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\102837at40674.cds.fasta | nseq=5 | len_before=[1677–3780] | len_after=[200–268]
# 1030at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1030at40674.cds.fasta | nseq=21 | len_before=[246–621] | len_after=[201–298]
# 103134at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103134at40674.cds.fasta | nseq=381 | len_before=[837–1299] | len_after=[200–300]
# 103140at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103140at40674.cds.fasta | nseq=5 | len_before=[375–1206] | len_after=[222–266]
# 103214at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103214at40674.cds.fasta | nseq=6 | len_before=[264–522] | len_after=[234–274]
# 103249at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103249at40674.cds.fasta | nseq=487 | len_before=[504–2136] | len_after=[200–300]
# 103280at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103280at40674.cds.fasta | nseq=25 | len_before=[252–2084] | len_after=[216–294]
# 103294at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103294at40674.cds.fasta | nseq=378 | len_before=[255–1416] | len_after=[200–300]
# 10332at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10332at40674.cds.fasta | nseq=420 | len_before=[366–1605] | len_after=[200–299]
# 10333at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10333at40674.cds.fasta | nseq=4 | len_before=[852–948] | len_after=[221–274]
# 103424at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103424at40674.cds.fasta | nseq=154 | len_before=[681–3564] | len_after=[201–300]
# 103430at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103430at40674.cds.fasta | nseq=414 | len_before=[228–579] | len_after=[200–300]
# 103472at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103472at40674.cds.fasta | nseq=51 | len_before=[201–2055] | len_after=[201–299]
# 103633at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103633at40674.cds.fasta | nseq=546 | len_before=[387–1758] | len_after=[200–300]
# 103647at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103647at40674.cds.fasta | nseq=20 | len_before=[1374–2685] | len_after=[215–296]
# 10367at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10367at40674.cds.fasta | nseq=291 | len_before=[201–1371] | len_after=[200–300]
# 103784at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\103784at40674.cds.fasta | nseq=8 | len_before=[282–600] | len_after=[202–286]
# 10392at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10392at40674.cds.fasta | nseq=12 | len_before=[330–690] | len_after=[214–299]
# 104008at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104008at40674.cds.fasta | nseq=341 | len_before=[171–660] | len_after=[171–299]
# 104048at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104048at40674.cds.fasta | nseq=201 | len_before=[330–1938] | len_after=[200–299]
# 1040at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1040at40674.cds.fasta | nseq=14 | len_before=[312–525] | len_after=[201–294]
# 10421at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10421at40674.cds.fasta | nseq=781 | len_before=[204–1251] | len_after=[200–300]
# 10424at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10424at40674.cds.fasta | nseq=12 | len_before=[405–837] | len_after=[232–297]
# 104253at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104253at40674.cds.fasta | nseq=3 | len_before=[561–564] | len_after=[254–280]
# 104259at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104259at40674.cds.fasta | nseq=6 | len_before=[243–345] | len_after=[235–282]
# 10428at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10428at40674.cds.fasta | nseq=7 | len_before=[954–2175] | len_after=[221–285]
# 104324at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104324at40674.cds.fasta | nseq=6 | len_before=[411–411] | len_after=[207–286]
# 104505at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104505at40674.cds.fasta | nseq=386 | len_before=[537–4962] | len_after=[201–300]
# 104543at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104543at40674.cds.fasta | nseq=12 | len_before=[339–507] | len_after=[227–294]
# 10458at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10458at40674.cds.fasta | nseq=386 | len_before=[759–1935] | len_after=[200–300]
# 104764at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104764at40674.cds.fasta | nseq=20 | len_before=[219–1338] | len_after=[201–300]
# 104826at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104826at40674.cds.fasta | nseq=307 | len_before=[186–546] | len_after=[186–300]
# 104941at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104941at40674.cds.fasta | nseq=17 | len_before=[216–873] | len_after=[200–298]
# 104961at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\104961at40674.cds.fasta | nseq=4 | len_before=[588–648] | len_after=[230–300]
# 105005at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105005at40674.cds.fasta | nseq=391 | len_before=[222–2007] | len_after=[200–300]
# 105056at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105056at40674.cds.fasta | nseq=222 | len_before=[423–1872] | len_after=[200–300]
# 105076at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105076at40674.cds.fasta | nseq=49 | len_before=[726–978] | len_after=[203–298]
# 105090at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105090at40674.cds.fasta | nseq=368 | len_before=[258–3171] | len_after=[200–300]
# 105098at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105098at40674.cds.fasta | nseq=7 | len_before=[546–789] | len_after=[240–288]
# 105125at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105125at40674.cds.fasta | nseq=40 | len_before=[201–1764] | len_after=[200–291]
# 10522at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10522at40674.cds.fasta | nseq=20 | len_before=[252–612] | len_after=[216–296]
# 105303at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105303at40674.cds.fasta | nseq=21 | len_before=[1437–1764] | len_after=[206–293]
# 105353at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105353at40674.cds.fasta | nseq=26 | len_before=[204–1236] | len_after=[200–299]
# 105505at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105505at40674.cds.fasta | nseq=17 | len_before=[417–1281] | len_after=[200–298]
# 105544at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105544at40674.cds.fasta | nseq=431 | len_before=[207–1065] | len_after=[200–300]
# 105546at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105546at40674.cds.fasta | nseq=21 | len_before=[252–819] | len_after=[252–294]
# 105755at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105755at40674.cds.fasta | nseq=412 | len_before=[321–2631] | len_after=[200–300]
# 105795at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105795at40674.cds.fasta | nseq=22 | len_before=[285–696] | len_after=[205–295]
# 105796at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105796at40674.cds.fasta | nseq=14 | len_before=[228–897] | len_after=[227–289]
# 105862at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105862at40674.cds.fasta | nseq=396 | len_before=[420–3273] | len_after=[200–300]
# 105918at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105918at40674.cds.fasta | nseq=15 | len_before=[342–606] | len_after=[205–296]
# 10597at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10597at40674.cds.fasta | nseq=6 | len_before=[219–294] | len_after=[219–294]
# 105993at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105993at40674.cds.fasta | nseq=8 | len_before=[243–315] | len_after=[243–272]
# 105at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\105at40674.cds.fasta | nseq=33 | len_before=[219–678] | len_after=[207–294]
# 106068at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106068at40674.cds.fasta | nseq=295 | len_before=[579–1260] | len_after=[200–300]
# 106081at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106081at40674.cds.fasta | nseq=402 | len_before=[381–2112] | len_after=[200–299]
# 106115at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106115at40674.cds.fasta | nseq=4 | len_before=[432–539] | len_after=[204–299]
# 106189at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106189at40674.cds.fasta | nseq=184 | len_before=[210–843] | len_after=[201–300]
# 10622at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10622at40674.cds.fasta | nseq=267 | len_before=[1008–2082] | len_after=[200–300]
# 10636at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10636at40674.cds.fasta | nseq=46 | len_before=[255–2487] | len_after=[202–298]
# 10637at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10637at40674.cds.fasta | nseq=4 | len_before=[279–370] | len_after=[241–279]
# 106619at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106619at40674.cds.fasta | nseq=375 | len_before=[180–2244] | len_after=[180–300]
# 10667at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10667at40674.cds.fasta | nseq=7 | len_before=[213–234] | len_after=[213–234]
# 106725at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106725at40674.cds.fasta | nseq=387 | len_before=[510–3897] | len_after=[200–300]
# 10675at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10675at40674.cds.fasta | nseq=32 | len_before=[189–2028] | len_after=[189–295]
# 106787at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106787at40674.cds.fasta | nseq=387 | len_before=[216–1536] | len_after=[200–300]
# 106831at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106831at40674.cds.fasta | nseq=286 | len_before=[2592–3681] | len_after=[200–300]
# 106840at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106840at40674.cds.fasta | nseq=8 | len_before=[327–468] | len_after=[216–263]
# 106895at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106895at40674.cds.fasta | nseq=360 | len_before=[891–3045] | len_after=[200–299]
# 106975at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\106975at40674.cds.fasta | nseq=388 | len_before=[1089–1938] | len_after=[201–300]
# 107045at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107045at40674.cds.fasta | nseq=384 | len_before=[567–1452] | len_after=[200–300]
# 107054at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107054at40674.cds.fasta | nseq=396 | len_before=[882–3000] | len_after=[200–300]
# 107168at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107168at40674.cds.fasta | nseq=6 | len_before=[249–249] | len_after=[249–249]
# 10746at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10746at40674.cds.fasta | nseq=341 | len_before=[369–771] | len_after=[200–300]
# 10750at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10750at40674.cds.fasta | nseq=373 | len_before=[348–2259] | len_after=[200–300]
# 107523at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107523at40674.cds.fasta | nseq=4 | len_before=[987–1149] | len_after=[204–270]
# 107552at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107552at40674.cds.fasta | nseq=99 | len_before=[204–2193] | len_after=[200–300]
# 107623at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107623at40674.cds.fasta | nseq=5 | len_before=[582–810] | len_after=[249–299]
# 107722at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107722at40674.cds.fasta | nseq=4 | len_before=[558–615] | len_after=[209–296]
# 107756at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107756at40674.cds.fasta | nseq=150 | len_before=[315–1407] | len_after=[200–300]
# 107812at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107812at40674.cds.fasta | nseq=414 | len_before=[231–2076] | len_after=[200–300]
# 107884at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107884at40674.cds.fasta | nseq=387 | len_before=[543–3096] | len_after=[200–300]
# 107889at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107889at40674.cds.fasta | nseq=7 | len_before=[480–717] | len_after=[228–255]
# 107972at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\107972at40674.cds.fasta | nseq=9 | len_before=[225–438] | len_after=[225–291]
# 108013at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108013at40674.cds.fasta | nseq=382 | len_before=[723–1644] | len_after=[200–300]
# 108022at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108022at40674.cds.fasta | nseq=27 | len_before=[804–1113] | len_after=[200–300]
# 10805at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10805at40674.cds.fasta | nseq=370 | len_before=[465–3350] | len_after=[200–300]
# 108141at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108141at40674.cds.fasta | nseq=279 | len_before=[633–2967] | len_after=[200–300]
# 108142at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108142at40674.cds.fasta | nseq=394 | len_before=[1113–2139] | len_after=[200–300]
# 108147at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108147at40674.cds.fasta | nseq=400 | len_before=[771–6105] | len_after=[200–300]
# 108331at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108331at40674.cds.fasta | nseq=3 | len_before=[255–255] | len_after=[255–255]
# 108349at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108349at40674.cds.fasta | nseq=6 | len_before=[204–204] | len_after=[204–204]
# 108396at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108396at40674.cds.fasta | nseq=386 | len_before=[477–2145] | len_after=[200–300]
# 10857at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10857at40674.cds.fasta | nseq=275 | len_before=[561–4233] | len_after=[200–300]
# 108615at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108615at40674.cds.fasta | nseq=418 | len_before=[390–2853] | len_after=[200–300]
# 108780at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108780at40674.cds.fasta | nseq=393 | len_before=[246–1008] | len_after=[200–300]
# 108809at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108809at40674.cds.fasta | nseq=413 | len_before=[648–3135] | len_after=[200–300]
# 108820at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108820at40674.cds.fasta | nseq=17 | len_before=[360–1347] | len_after=[202–285]
# 10888at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\10888at40674.cds.fasta | nseq=7 | len_before=[210–453] | len_after=[210–300]
# 108900at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108900at40674.cds.fasta | nseq=271 | len_before=[999–1563] | len_after=[201–300]
# 108911at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108911at40674.cds.fasta | nseq=314 | len_before=[351–2727] | len_after=[200–300]
# 108995at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108995at40674.cds.fasta | nseq=398 | len_before=[480–2841] | len_after=[200–300]
# 108999at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\108999at40674.cds.fasta | nseq=395 | len_before=[390–2460] | len_after=[200–300]
# 109019at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109019at40674.cds.fasta | nseq=389 | len_before=[629–3642] | len_after=[200–300]
# 109224at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109224at40674.cds.fasta | nseq=17 | len_before=[384–4116] | len_after=[200–297]
# 109347at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109347at40674.cds.fasta | nseq=395 | len_before=[444–3477] | len_after=[200–300]
# 109408at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109408at40674.cds.fasta | nseq=390 | len_before=[258–2442] | len_after=[200–300]
# 109518at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109518at40674.cds.fasta | nseq=397 | len_before=[924–3519] | len_after=[200–300]
# 109537at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109537at40674.cds.fasta | nseq=406 | len_before=[546–3072] | len_after=[200–300]
# 109556at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109556at40674.cds.fasta | nseq=428 | len_before=[353–2127] | len_after=[200–300]
# 109578at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109578at40674.cds.fasta | nseq=358 | len_before=[273–789] | len_after=[200–300]
# 109660at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109660at40674.cds.fasta | nseq=450 | len_before=[699–1236] | len_after=[200–300]
# 109689at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109689at40674.cds.fasta | nseq=5 | len_before=[429–579] | len_after=[200–262]
# 109712at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109712at40674.cds.fasta | nseq=359 | len_before=[174–2514] | len_after=[174–300]
# 109796at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109796at40674.cds.fasta | nseq=389 | len_before=[393–1674] | len_after=[200–300]
# 109981at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\109981at40674.cds.fasta | nseq=384 | len_before=[234–5220] | len_after=[200–300]
# 1101at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1101at40674.cds.fasta | nseq=136 | len_before=[315–3462] | len_after=[201–299]
# 110308at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110308at40674.cds.fasta | nseq=397 | len_before=[456–2076] | len_after=[200–300]
# 110340at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110340at40674.cds.fasta | nseq=399 | len_before=[984–2991] | len_after=[200–300]
# 110393at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110393at40674.cds.fasta | nseq=9 | len_before=[210–924] | len_after=[210–282]
# 11049at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11049at40674.cds.fasta | nseq=9 | len_before=[528–1125] | len_after=[202–298]
# 110522at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110522at40674.cds.fasta | nseq=10 | len_before=[243–594] | len_after=[219–297]
# 110554at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110554at40674.cds.fasta | nseq=217 | len_before=[789–1689] | len_after=[200–299]
# 110658at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110658at40674.cds.fasta | nseq=370 | len_before=[219–1410] | len_after=[200–300]
# 110747at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\110747at40674.cds.fasta | nseq=4 | len_before=[327–351] | len_after=[230–289]
# 1107at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1107at40674.cds.fasta | nseq=386 | len_before=[324–1143] | len_after=[200–300]
# 11092at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11092at40674.cds.fasta | nseq=12 | len_before=[1026–1215] | len_after=[202–294]
# 111008at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111008at40674.cds.fasta | nseq=17 | len_before=[207–483] | len_after=[207–300]
# 111081at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111081at40674.cds.fasta | nseq=3 | len_before=[1542–1545] | len_after=[206–263]
# 111125at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111125at40674.cds.fasta | nseq=18 | len_before=[933–951] | len_after=[202–299]
# 1112at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1112at40674.cds.fasta | nseq=25 | len_before=[246–2070] | len_after=[211–290]
# 111325at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111325at40674.cds.fasta | nseq=410 | len_before=[507–3756] | len_after=[200–300]
# 111385at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111385at40674.cds.fasta | nseq=372 | len_before=[306–1833] | len_after=[200–300]
# 111412at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111412at40674.cds.fasta | nseq=4 | len_before=[237–249] | len_after=[237–249]
# 111420at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111420at40674.cds.fasta | nseq=397 | len_before=[603–2796] | len_after=[200–300]
# 11157at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11157at40674.cds.fasta | nseq=5 | len_before=[234–456] | len_after=[227–271]
# 111739at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111739at40674.cds.fasta | nseq=10 | len_before=[306–744] | len_after=[203–289]
# 111763at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111763at40674.cds.fasta | nseq=3 | len_before=[486–486] | len_after=[241–288]
# 111842at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111842at40674.cds.fasta | nseq=404 | len_before=[477–3354] | len_after=[201–300]
# 11184at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11184at40674.cds.fasta | nseq=12 | len_before=[204–531] | len_after=[204–300]
# 11191at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11191at40674.cds.fasta | nseq=384 | len_before=[1059–2124] | len_after=[200–300]
# 111963at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111963at40674.cds.fasta | nseq=70 | len_before=[780–1056] | len_after=[200–299]
# 111985at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\111985at40674.cds.fasta | nseq=178 | len_before=[258–2327] | len_after=[200–300]
# 112035at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112035at40674.cds.fasta | nseq=499 | len_before=[417–3594] | len_after=[200–300]
# 112070at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112070at40674.cds.fasta | nseq=401 | len_before=[732–6453] | len_after=[200–300]
# 112093at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112093at40674.cds.fasta | nseq=402 | len_before=[486–2214] | len_after=[200–300]
# 112165at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112165at40674.cds.fasta | nseq=360 | len_before=[270–3099] | len_after=[200–300]
# 112206at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112206at40674.cds.fasta | nseq=211 | len_before=[312–1866] | len_after=[200–300]
# 112253at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112253at40674.cds.fasta | nseq=12 | len_before=[267–450] | len_after=[207–286]
# 112271at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112271at40674.cds.fasta | nseq=44 | len_before=[249–753] | len_after=[200–300]
# 112326at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112326at40674.cds.fasta | nseq=397 | len_before=[1167–2769] | len_after=[200–300]
# 112452at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112452at40674.cds.fasta | nseq=239 | len_before=[348–1233] | len_after=[200–300]
# 112494at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112494at40674.cds.fasta | nseq=43 | len_before=[435–777] | len_after=[200–300]
# 112496at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112496at40674.cds.fasta | nseq=51 | len_before=[240–1068] | len_after=[200–299]
# 112532at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112532at40674.cds.fasta | nseq=357 | len_before=[335–1002] | len_after=[200–300]
# 112608at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112608at40674.cds.fasta | nseq=389 | len_before=[201–3306] | len_after=[201–300]
# 112657at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112657at40674.cds.fasta | nseq=408 | len_before=[573–2673] | len_after=[200–300]
# 112672at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112672at40674.cds.fasta | nseq=30 | len_before=[639–1131] | len_after=[201–294]
# 112739at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112739at40674.cds.fasta | nseq=3 | len_before=[414–414] | len_after=[219–289]
# 112896at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112896at40674.cds.fasta | nseq=661 | len_before=[402–1380] | len_after=[200–300]
# 112984at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112984at40674.cds.fasta | nseq=393 | len_before=[267–2004] | len_after=[200–300]
# 112988at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\112988at40674.cds.fasta | nseq=367 | len_before=[273–1320] | len_after=[200–300]
# 113020at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113020at40674.cds.fasta | nseq=403 | len_before=[237–1005] | len_after=[200–300]
# 113022at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113022at40674.cds.fasta | nseq=348 | len_before=[228–1062] | len_after=[200–300]
# 11306at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11306at40674.cds.fasta | nseq=364 | len_before=[486–1620] | len_after=[200–300]
# 113102at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113102at40674.cds.fasta | nseq=300 | len_before=[2004–6624] | len_after=[200–300]
# 113225at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113225at40674.cds.fasta | nseq=364 | len_before=[420–1083] | len_after=[200–300]
# 113333at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113333at40674.cds.fasta | nseq=456 | len_before=[204–2340] | len_after=[200–300]
# 11334at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11334at40674.cds.fasta | nseq=15 | len_before=[387–2025] | len_after=[200–300]
# 113390at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113390at40674.cds.fasta | nseq=35 | len_before=[759–1362] | len_after=[205–300]
# 113631at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113631at40674.cds.fasta | nseq=5 | len_before=[327–327] | len_after=[230–293]
# 113664at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113664at40674.cds.fasta | nseq=4 | len_before=[972–999] | len_after=[242–291]
# 113694at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113694at40674.cds.fasta | nseq=417 | len_before=[228–1260] | len_after=[200–300]
# 113726at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113726at40674.cds.fasta | nseq=211 | len_before=[402–2346] | len_after=[200–299]
# 113730at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113730at40674.cds.fasta | nseq=370 | len_before=[417–2247] | len_after=[200–300]
# 113884at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113884at40674.cds.fasta | nseq=398 | len_before=[1107–7158] | len_after=[200–300]
# 113940at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\113940at40674.cds.fasta | nseq=4 | len_before=[660–660] | len_after=[252–287]
# 1139at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1139at40674.cds.fasta | nseq=403 | len_before=[360–3102] | len_after=[200–300]
# 114024at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114024at40674.cds.fasta | nseq=10 | len_before=[255–264] | len_after=[255–264]
# 114026at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114026at40674.cds.fasta | nseq=370 | len_before=[1101–1968] | len_after=[200–300]
# 114209at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114209at40674.cds.fasta | nseq=9 | len_before=[207–666] | len_after=[207–300]
# 114249at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114249at40674.cds.fasta | nseq=9 | len_before=[996–1002] | len_after=[225–287]
# 114256at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114256at40674.cds.fasta | nseq=15 | len_before=[201–387] | len_after=[201–300]
# 114307at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114307at40674.cds.fasta | nseq=395 | len_before=[1281–4314] | len_after=[200–300]
# 114510at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114510at40674.cds.fasta | nseq=396 | len_before=[321–3063] | len_after=[200–300]
# 114533at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114533at40674.cds.fasta | nseq=12 | len_before=[225–842] | len_after=[225–255]
# 114640at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114640at40674.cds.fasta | nseq=35 | len_before=[714–2159] | len_after=[203–299]
# 114920at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114920at40674.cds.fasta | nseq=397 | len_before=[1014–7815] | len_after=[200–300]
# 114989at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\114989at40674.cds.fasta | nseq=5 | len_before=[1380–1872] | len_after=[232–279]
# 115012at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115012at40674.cds.fasta | nseq=405 | len_before=[558–3720] | len_after=[200–300]
# 115107at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115107at40674.cds.fasta | nseq=399 | len_before=[990–2196] | len_after=[200–300]
# 115168at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115168at40674.cds.fasta | nseq=783 | len_before=[303–2412] | len_after=[200–300]
# 115206at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115206at40674.cds.fasta | nseq=406 | len_before=[1137–3462] | len_after=[200–300]
# 115322at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115322at40674.cds.fasta | nseq=395 | len_before=[573–2958] | len_after=[200–300]
# 11543at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11543at40674.cds.fasta | nseq=394 | len_before=[414–2949] | len_after=[200–300]
# 11544at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11544at40674.cds.fasta | nseq=385 | len_before=[474–2010] | len_after=[200–300]
# 115472at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115472at40674.cds.fasta | nseq=112 | len_before=[411–1185] | len_after=[200–300]
# 115532at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115532at40674.cds.fasta | nseq=382 | len_before=[579–1212] | len_after=[200–300]
# 115537at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115537at40674.cds.fasta | nseq=203 | len_before=[228–1428] | len_after=[200–300]
# 115550at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115550at40674.cds.fasta | nseq=7 | len_before=[210–996] | len_after=[210–260]
# 115605at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115605at40674.cds.fasta | nseq=391 | len_before=[1212–2865] | len_after=[200–300]
# 115842at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115842at40674.cds.fasta | nseq=3 | len_before=[1350–1350] | len_after=[212–291]
# 115852at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115852at40674.cds.fasta | nseq=397 | len_before=[315–2613] | len_after=[200–300]
# 115878at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115878at40674.cds.fasta | nseq=3 | len_before=[384–1026] | len_after=[221–276]
# 115900at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\115900at40674.cds.fasta | nseq=384 | len_before=[291–2046] | len_after=[200–300]
# 116039at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116039at40674.cds.fasta | nseq=396 | len_before=[288–3285] | len_after=[200–300]
# 116043at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116043at40674.cds.fasta | nseq=868 | len_before=[261–1428] | len_after=[200–300]
# 116051at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116051at40674.cds.fasta | nseq=11 | len_before=[921–933] | len_after=[209–292]
# 116068at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116068at40674.cds.fasta | nseq=3 | len_before=[519–654] | len_after=[225–248]
# 1160at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1160at40674.cds.fasta | nseq=3 | len_before=[204–390] | len_after=[204–226]
# 116110at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116110at40674.cds.fasta | nseq=399 | len_before=[1476–4227] | len_after=[200–300]
# 116134at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116134at40674.cds.fasta | nseq=650 | len_before=[219–1032] | len_after=[200–300]
# 116166at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116166at40674.cds.fasta | nseq=391 | len_before=[381–3084] | len_after=[200–300]
# 116204at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116204at40674.cds.fasta | nseq=305 | len_before=[474–6495] | len_after=[200–300]
# 116220at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116220at40674.cds.fasta | nseq=3 | len_before=[246–309] | len_after=[209–246]
# 116375at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116375at40674.cds.fasta | nseq=357 | len_before=[303–1026] | len_after=[200–300]
# 116452at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116452at40674.cds.fasta | nseq=246 | len_before=[348–597] | len_after=[200–300]
# 116464at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116464at40674.cds.fasta | nseq=5 | len_before=[915–1149] | len_after=[209–299]
# 116487at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116487at40674.cds.fasta | nseq=76 | len_before=[246–387] | len_after=[200–300]
# 116556at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116556at40674.cds.fasta | nseq=394 | len_before=[231–1404] | len_after=[200–300]
# 116580at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116580at40674.cds.fasta | nseq=247 | len_before=[1647–2475] | len_after=[200–300]
# 116638at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116638at40674.cds.fasta | nseq=377 | len_before=[519–1335] | len_after=[200–300]
# 116678at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116678at40674.cds.fasta | nseq=391 | len_before=[276–2358] | len_after=[200–300]
# 116742at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116742at40674.cds.fasta | nseq=2 | len_before=[381–381] | len_after=[215–276]
# 11692at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11692at40674.cds.fasta | nseq=390 | len_before=[497–4923] | len_after=[200–300]
# 116948at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116948at40674.cds.fasta | nseq=7 | len_before=[210–552] | len_after=[210–291]
# 116968at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\116968at40674.cds.fasta | nseq=7 | len_before=[933–933] | len_after=[211–276]
# 117072at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117072at40674.cds.fasta | nseq=22 | len_before=[222–1146] | len_after=[202–296]
# 11717at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11717at40674.cds.fasta | nseq=381 | len_before=[597–2352] | len_after=[200–300]
# 117224at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117224at40674.cds.fasta | nseq=13 | len_before=[348–618] | len_after=[204–297]
# 117386at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117386at40674.cds.fasta | nseq=3 | len_before=[255–267] | len_after=[255–267]
# 117391at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117391at40674.cds.fasta | nseq=397 | len_before=[646–3528] | len_after=[200–300]
# 117406at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117406at40674.cds.fasta | nseq=113 | len_before=[300–912] | len_after=[200–300]
# 117590at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117590at40674.cds.fasta | nseq=3 | len_before=[558–558] | len_after=[208–256]
# 11763at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11763at40674.cds.fasta | nseq=9 | len_before=[312–465] | len_after=[208–274]
# 11774at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\11774at40674.cds.fasta | nseq=17 | len_before=[648–3147] | len_after=[207–291]
# 117759at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117759at40674.cds.fasta | nseq=420 | len_before=[441–2706] | len_after=[200–300]
# 117938at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\117938at40674.cds.fasta | nseq=403 | len_before=[297–2382] | len_after=[200–300]
# 118032at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118032at40674.cds.fasta | nseq=399 | len_before=[1026–2931] | len_after=[200–300]
# 118064at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118064at40674.cds.fasta | nseq=384 | len_before=[372–1038] | len_after=[200–300]
# 118078at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118078at40674.cds.fasta | nseq=399 | len_before=[207–1923] | len_after=[200–300]
# 118113at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118113at40674.cds.fasta | nseq=6 | len_before=[222–480] | len_after=[208–255]
# 118174at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118174at40674.cds.fasta | nseq=425 | len_before=[201–3042] | len_after=[200–300]
# 118192at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118192at40674.cds.fasta | nseq=6 | len_before=[318–327] | len_after=[211–271]
# 118231at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118231at40674.cds.fasta | nseq=402 | len_before=[441–2474] | len_after=[200–300]
# 118246at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118246at40674.cds.fasta | nseq=440 | len_before=[312–1761] | len_after=[200–300]
# 118348at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118348at40674.cds.fasta | nseq=381 | len_before=[336–1308] | len_after=[200–300]
# 118591at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118591at40674.cds.fasta | nseq=9 | len_before=[933–933] | len_after=[227–296]
# 118616at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118616at40674.cds.fasta | nseq=9 | len_before=[390–498] | len_after=[204–246]
# 118708at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\118708at40674.cds.fasta | nseq=143 | len_before=[312–1899] | len_after=[200–300]
# ...
# 126968at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\126968at40674.cds.fasta | nseq=14 | len_before=[228–744] | len_after=[203–300]
# 12699at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12699at40674.cds.fasta | nseq=35 | len_before=[216–981] | len_after=[207–294]
# 127013at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127013at40674.cds.fasta | nseq=387 | len_before=[312–3471] | len_after=[200–300]
# 127055at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127055at40674.cds.fasta | nseq=380 | len_before=[870–1206] | len_after=[200–299]
# 127189at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127189at40674.cds.fasta | nseq=385 | len_before=[963–1335] | len_after=[200–300]
# 12726at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12726at40674.cds.fasta | nseq=322 | len_before=[249–1845] | len_after=[200–300]
# 127309at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127309at40674.cds.fasta | nseq=3 | len_before=[711–744] | len_after=[222–268]
# 127321at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127321at40674.cds.fasta | nseq=400 | len_before=[1404–2493] | len_after=[200–300]
# 127360at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127360at40674.cds.fasta | nseq=393 | len_before=[507–2571] | len_after=[200–300]
# 127446at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127446at40674.cds.fasta | nseq=395 | len_before=[537–7965] | len_after=[201–300]
# 127495at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127495at40674.cds.fasta | nseq=163 | len_before=[309–2091] | len_after=[200–300]
# 127519at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127519at40674.cds.fasta | nseq=8 | len_before=[204–630] | len_after=[204–297]
# 127604at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127604at40674.cds.fasta | nseq=8 | len_before=[252–498] | len_after=[200–271]
# 127689at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127689at40674.cds.fasta | nseq=5 | len_before=[651–750] | len_after=[207–283]
# 127784at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127784at40674.cds.fasta | nseq=374 | len_before=[357–3042] | len_after=[200–300]
# 127913at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127913at40674.cds.fasta | nseq=420 | len_before=[516–2787] | len_after=[200–300]
# 127924at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\127924at40674.cds.fasta | nseq=3 | len_before=[654–654] | len_after=[222–289]
# 128064at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128064at40674.cds.fasta | nseq=383 | len_before=[291–1551] | len_after=[200–300]
# 128236at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128236at40674.cds.fasta | nseq=770 | len_before=[333–1968] | len_after=[200–300]
# 128259at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128259at40674.cds.fasta | nseq=52 | len_before=[246–2370] | len_after=[202–293]
# 128329at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128329at40674.cds.fasta | nseq=387 | len_before=[477–1191] | len_after=[200–300]
# 128369at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128369at40674.cds.fasta | nseq=401 | len_before=[336–2148] | len_after=[200–300]
# 128441at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128441at40674.cds.fasta | nseq=916 | len_before=[261–3759] | len_after=[200–300]
# 128511at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128511at40674.cds.fasta | nseq=3 | len_before=[204–207] | len_after=[204–207]
# 128533at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128533at40674.cds.fasta | nseq=5 | len_before=[933–1035] | len_after=[250–284]
# 128625at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128625at40674.cds.fasta | nseq=20 | len_before=[171–276] | len_after=[171–276]
# 128629at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128629at40674.cds.fasta | nseq=392 | len_before=[248–4338] | len_after=[200–300]
# 128771at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128771at40674.cds.fasta | nseq=393 | len_before=[225–1821] | len_after=[200–300]
# 128863at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128863at40674.cds.fasta | nseq=342 | len_before=[234–1464] | len_after=[200–300]
# 12886at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12886at40674.cds.fasta | nseq=3 | len_before=[216–321] | len_after=[216–288]
# 128871at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128871at40674.cds.fasta | nseq=395 | len_before=[729–2396] | len_after=[200–300]
# 128953at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128953at40674.cds.fasta | nseq=23 | len_before=[159–1137] | len_after=[159–297]
# 128978at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128978at40674.cds.fasta | nseq=603 | len_before=[429–1890] | len_after=[200–300]
# 128982at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\128982at40674.cds.fasta | nseq=5 | len_before=[492–492] | len_after=[227–292]
# 129004at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129004at40674.cds.fasta | nseq=399 | len_before=[525–3996] | len_after=[200–300]
# 129142at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129142at40674.cds.fasta | nseq=16 | len_before=[561–606] | len_after=[202–300]
# 12917at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12917at40674.cds.fasta | nseq=363 | len_before=[360–951] | len_after=[200–300]
# 129409at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129409at40674.cds.fasta | nseq=3 | len_before=[876–888] | len_after=[207–273]
# 129411at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129411at40674.cds.fasta | nseq=12 | len_before=[219–672] | len_after=[210–299]
# 129490at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129490at40674.cds.fasta | nseq=8 | len_before=[252–363] | len_after=[232–289]
# 1294at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1294at40674.cds.fasta | nseq=394 | len_before=[1074–2229] | len_after=[200–300]
# 129776at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129776at40674.cds.fasta | nseq=4 | len_before=[588–588] | len_after=[200–298]
# 12994at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12994at40674.cds.fasta | nseq=401 | len_before=[489–3072] | len_after=[200–300]
# 12996at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\12996at40674.cds.fasta | nseq=4 | len_before=[534–687] | len_after=[224–289]
# 129998at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\129998at40674.cds.fasta | nseq=401 | len_before=[477–3268] | len_after=[200–300]
# 130018at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130018at40674.cds.fasta | nseq=433 | len_before=[447–1428] | len_after=[200–300]
# 130115at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130115at40674.cds.fasta | nseq=530 | len_before=[417–1920] | len_after=[200–300]
# 130200at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130200at40674.cds.fasta | nseq=6 | len_before=[213–495] | len_after=[213–255]
# 13025at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13025at40674.cds.fasta | nseq=340 | len_before=[387–1725] | len_after=[200–300]
# 130341at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130341at40674.cds.fasta | nseq=306 | len_before=[525–2763] | len_after=[200–300]
# 130627at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130627at40674.cds.fasta | nseq=383 | len_before=[1437–6459] | len_after=[200–300]
# 130633at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130633at40674.cds.fasta | nseq=393 | len_before=[174–969] | len_after=[174–300]
# 13075at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13075at40674.cds.fasta | nseq=21 | len_before=[291–1083] | len_after=[210–300]
# 130827at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130827at40674.cds.fasta | nseq=157 | len_before=[201–1461] | len_after=[200–300]
# 130857at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130857at40674.cds.fasta | nseq=414 | len_before=[282–1515] | len_after=[200–300]
# 130964at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\130964at40674.cds.fasta | nseq=397 | len_before=[639–3789] | len_after=[200–300]
# 131096at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131096at40674.cds.fasta | nseq=10 | len_before=[402–555] | len_after=[200–290]
# 131185at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131185at40674.cds.fasta | nseq=538 | len_before=[201–4263] | len_after=[200–300]
# 131238at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131238at40674.cds.fasta | nseq=404 | len_before=[987–5571] | len_after=[200–300]
# 131256at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131256at40674.cds.fasta | nseq=3 | len_before=[483–483] | len_after=[217–264]
# 131346at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131346at40674.cds.fasta | nseq=412 | len_before=[264–1725] | len_after=[200–300]
# 131380at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131380at40674.cds.fasta | nseq=3 | len_before=[360–366] | len_after=[224–271]
# 131404at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131404at40674.cds.fasta | nseq=430 | len_before=[441–3960] | len_after=[200–300]
# 13148at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13148at40674.cds.fasta | nseq=55 | len_before=[204–882] | len_after=[201–297]
# 131579at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131579at40674.cds.fasta | nseq=58 | len_before=[636–1269] | len_after=[200–299]
# 13158at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13158at40674.cds.fasta | nseq=402 | len_before=[393–3780] | len_after=[200–300]
# 131594at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131594at40674.cds.fasta | nseq=8 | len_before=[270–432] | len_after=[205–289]
# 131687at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131687at40674.cds.fasta | nseq=119 | len_before=[261–2361] | len_after=[203–300]
# 131719at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131719at40674.cds.fasta | nseq=3 | len_before=[321–321] | len_after=[221–272]
# 13189at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13189at40674.cds.fasta | nseq=495 | len_before=[330–2589] | len_after=[200–300]
# 131900at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\131900at40674.cds.fasta | nseq=14 | len_before=[921–936] | len_after=[200–294]
# 13203at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13203at40674.cds.fasta | nseq=380 | len_before=[177–1065] | len_after=[177–300]
# 13206at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13206at40674.cds.fasta | nseq=151 | len_before=[132–549] | len_after=[132–300]
# 13218at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13218at40674.cds.fasta | nseq=8 | len_before=[453–717] | len_after=[206–292]
# 13220at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13220at40674.cds.fasta | nseq=8 | len_before=[213–534] | len_after=[213–300]
# 132255at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\132255at40674.cds.fasta | nseq=13 | len_before=[273–1842] | len_after=[201–285]
# 132358at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\132358at40674.cds.fasta | nseq=411 | len_before=[444–3843] | len_after=[200–300]
# 132450at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\132450at40674.cds.fasta | nseq=7 | len_before=[531–573] | len_after=[221–287]
# 13258at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\13258at40674.cds.fasta | nseq=394 | len_before=[240–2148] | len_after=[200–300]
# 132697at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\132697at40674.cds.fasta | nseq=7 | len_before=[657–717] | len_after=[207–298]
# 133004at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133004at40674.cds.fasta | nseq=1481 | len_before=[213–9258] | len_after=[200–300]
# 133021at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133021at40674.cds.fasta | nseq=61 | len_before=[285–1749] | len_after=[200–298]
# 133049at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133049at40674.cds.fasta | nseq=122 | len_before=[372–3621] | len_after=[200–300]
# 133051at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133051at40674.cds.fasta | nseq=390 | len_before=[1491–2580] | len_after=[200–300]
# 133059at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133059at40674.cds.fasta | nseq=396 | len_before=[360–1998] | len_after=[200–300]
# 1330at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1330at40674.cds.fasta | nseq=381 | len_before=[447–1101] | len_after=[200–300]
# 133184at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133184at40674.cds.fasta | nseq=5 | len_before=[492–519] | len_after=[203–279]
# 1331at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\1331at40674.cds.fasta | nseq=5 | len_before=[216–597] | len_after=[216–292]
# 133312at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133312at40674.cds.fasta | nseq=3 | len_before=[264–441] | len_after=[264–287]
# 133333at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133333at40674.cds.fasta | nseq=28 | len_before=[279–1458] | len_after=[211–300]
# 133360at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133360at40674.cds.fasta | nseq=415 | len_before=[198–2361] | len_after=[198–300]
# 133491at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133491at40674.cds.fasta | nseq=6 | len_before=[231–744] | len_after=[208–280]
# 133542at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133542at40674.cds.fasta | nseq=19 | len_before=[570–963] | len_after=[216–294]
# 133576at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133576at40674.cds.fasta | nseq=4 | len_before=[387–450] | len_after=[231–273]
# 133808at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133808at40674.cds.fasta | nseq=20 | len_before=[687–813] | len_after=[203–298]
# 133846at40674.cds.fasta -> ..\datasets\fasta_files\orthodb_v12\unique_no_ambig_imp_cut\133846at40674.cds.fasta | nseq=54 | len_before=[600–1296] | len_after=[200–295]
# Done.
